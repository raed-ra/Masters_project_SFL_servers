# %% [markdown]
# # FL vs SFL — Non-IID One-Label-per-Client, 3-Layer Model
#
# This notebook compares **Federated Learning (FL)** and **Split Federated Learning (SFL / Design 1)** on MNIST under an extreme non-IID setting.
#
# **Non-IID setup:** each client receives data from only one label. With MNIST, this notebook uses **10 clients** so that labels 0–9 are all represented.
#
# The model architecture is now a 3-layer MLP:
#
# ```text
# Full FL model: 784 -> 256 -> 128 -> 10
# SFL client:    784 -> 256
# SFL server:    256 -> 128 -> 10
# ```
#
# So the SFL client has **1 trainable layer**, and the SFL server has **2 trainable layers**. The FL-only model also has the same 3 trainable layers for every client.
#
# After every global aggregation round, the notebook evaluates the global model on the full MNIST test set and stores one accuracy value per round for FL and SFL.

# %%
NOTEBOOK_ID = "05"

import os

# --------------------------------------------------
# Project/output folders
# --------------------------------------------------
# This notebook is normally run from the notebooks/ folder.
# If the current working directory is notebooks/, outputs are saved one level above it:
#     project_root/results/...
#     project_root/weights/...
# If the notebook is run from the project root instead, outputs are saved in that project root.
CURRENT_DIR = os.path.abspath(os.getcwd())
if os.path.basename(CURRENT_DIR).lower() == "notebooks":
    PROJECT_ROOT = os.path.dirname(CURRENT_DIR)
else:
    PROJECT_ROOT = CURRENT_DIR

DATA_DIR = os.path.join(PROJECT_ROOT, "data")

RESULTS_DIR = os.path.join(PROJECT_ROOT, "results")
CSV_DIR = os.path.join(RESULTS_DIR, "csv", NOTEBOOK_ID)
PLOTS_DIR = os.path.join(RESULTS_DIR, "plots", NOTEBOOK_ID)

WEIGHTS_DIR = os.path.join(PROJECT_ROOT, "weights", NOTEBOOK_ID)
FL_WEIGHTS_DIR = os.path.join(WEIGHTS_DIR, "fl")
SFL_WEIGHTS_DIR = os.path.join(WEIGHTS_DIR, "sfl")

# Corrected SFL structure:
#   1) client-side FL aggregation domain for client-owned layers fc1 + fc2
#   2) SFL server-side aggregation domain for server-owned layers fc3 + fc4
# The reconstructed full SFL model is saved only for evaluation/plotting.
# It is not treated as a deployed global model in the corrected architecture.
SFL_CLIENT_FL_WEIGHTS_DIR = os.path.join(SFL_WEIGHTS_DIR, "client_side_fl_aggregator")
SFL_SERVER_WEIGHTS_DIR = os.path.join(SFL_WEIGHTS_DIR, "sfl_server_aggregator")
SFL_EVAL_WEIGHTS_DIR = os.path.join(SFL_WEIGHTS_DIR, "evaluation_reconstructed_only")

for folder in [
    DATA_DIR,
    CSV_DIR,
    PLOTS_DIR,
    FL_WEIGHTS_DIR,
    SFL_CLIENT_FL_WEIGHTS_DIR,
    SFL_SERVER_WEIGHTS_DIR,
    SFL_EVAL_WEIGHTS_DIR,
]:
    os.makedirs(folder, exist_ok=True)

print("CURRENT_DIR:", CURRENT_DIR)
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
print("CSV_DIR:", CSV_DIR)
print("PLOTS_DIR:", PLOTS_DIR)
print("FL_WEIGHTS_DIR:", FL_WEIGHTS_DIR)
print("SFL_WEIGHTS_DIR:", SFL_WEIGHTS_DIR)
print("SFL_CLIENT_FL_WEIGHTS_DIR:", SFL_CLIENT_FL_WEIGHTS_DIR)
print("SFL_SERVER_WEIGHTS_DIR:", SFL_SERVER_WEIGHTS_DIR)
print("SFL_EVAL_WEIGHTS_DIR:", SFL_EVAL_WEIGHTS_DIR)
# Out:
# CURRENT_DIR: /home/raed/Documents/Masters_project_SFL_servers/notebooks
# PROJECT_ROOT: /home/raed/Documents/Masters_project_SFL_servers
# DATA_DIR: /home/raed/Documents/Masters_project_SFL_servers/data
# CSV_DIR: /home/raed/Documents/Masters_project_SFL_servers/results/csv/05
# PLOTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/results/plots/05
# FL_WEIGHTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/weights/05/fl
# SFL_WEIGHTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/weights/05/sfl
# SFL_CLIENT_FL_WEIGHTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/weights/05/sfl/client_side_fl_aggregator
# SFL_SERVER_WEIGHTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/weights/05/sfl/sfl_server_aggregator
# SFL_EVAL_WEIGHTS_DIR: /home/raed/Documents/Masters_project_SFL_servers/weights/05/sfl/evaluation_reconstructed_only

# %% [markdown]
# ## Updated model used in this version
#
# This notebook now uses a split-compatible **3-layer MLP**:
#
# ```text
# Full FL model: 784 -> 256 -> 128 -> 10
# SFL client:    784 -> 256
# SFL server:    256 -> 128 -> 10
# ```
#
# This gives exactly what we want for the SFL structure:
#
# - **Client side:** 1 trainable layer
# - **Server side:** 2 trainable layers
# - **FL model:** same complete 3-layer model on every client
#
# The split happens after the first hidden layer. The client produces the cut-layer activation of size 256, then the server completes the remaining two layers.

# %% [markdown]
# ## Learning-rate update
#
# This version uses the 3-layer architecture:
#
# ```text
# Full model:   784 -> 256 -> 128 -> 10
# SFL client:   784 -> 256
# SFL server:   256 -> 128 -> 10
# ```
#
# The notebook currently uses a fixed learning rate:
#
# ```python
# INITIAL_LR = 0.01
# LR_DECAY = 1.0
# current_lr = INITIAL_LR * LR_DECAY ** (round_id - 1)
# ```
#
# There is still no gradient clipping, no momentum, no BatchNorm, and no Adam. This keeps the FL/SFL equivalence check cleaner.

# %% [markdown]
# ## Diagnostic note: why the one-label non-IID accuracy may not improve
#
# This notebook uses the most extreme label-skew setting: **10 clients and each client receives only one MNIST class**.
#
# That means:
#
# - client 0 only trains on digit 0
# - client 1 only trains on digit 1
# - ...
# - client 9 only trains on digit 9
#
# Although all labels exist globally, each local optimisation step is based on only one class. This can cause **client drift**: each client update strongly pushes the model toward its own class. When FedAvg averages these highly biased updates, the global model may remain close to random guessing, especially with a deeper model, small number of rounds, and conservative learning-rate decay.
#
# Notebook 02 may behave differently because it uses a different FL implementation/model structure and different hyperparameters. In particular, notebook 02 uses a simpler `TwoNN` model and may use different learning rate, local epochs, and experiment settings. Notebook 05 is stricter because it is trying to make FL and SFL mathematically equivalent, so it uses the same starting model, deterministic client loaders, and compares FL and SFL global states using L2 distance.

# %%
import os
import copy
import time
import random
from collections import OrderedDict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms

# %% [markdown]
# ## 1. Reproducibility and device setup

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


SEED = 42
set_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Experiment settings and output folders
#
# Run this notebook from the repository root folder: `Masters_project_SFL_servers/`.

# %%
# MNIST has 10 labels, so using 10 clients gives one label per client and still covers all classes.
NUM_CLIENTS = 10
ROUNDS = 200
LOCAL_EPOCHS = 1
BATCH_SIZE = 64
TEST_BATCH_SIZE = 256

# Set to an integer such as 1000 for a quick test run.
# Set to None for the full one-label-per-client dataset.
MAX_SAMPLES_PER_CLIENT = None

print("CSV results will be saved to:", CSV_DIR)
print("Plots will be saved to:", PLOTS_DIR)
print("Weights will be saved to:", WEIGHTS_DIR)

# --------------------------------------------------
# Learning rate
# --------------------------------------------------
# Mild round-level LR decay for the 784 -> 256 -> 128 -> 64 -> 10 architecture.
# INITIAL_LR and LR_DECAY are defined only once in this notebook.
# The decay is applied once per communication round in the main training loop.
INITIAL_LR = 0.04
LR_DECAY = 0.995

def get_round_lr(round_id):
    """
    Return the learning rate for the current communication round.

    Example:
        round 1   -> 0.040000
        round 100 -> 0.04 * (0.995 ** 99)
    """
    return INITIAL_LR * (LR_DECAY ** (round_id - 1))
# Out:
# CSV results will be saved to: /home/raed/Documents/Masters_project_SFL_servers/results/csv/05
# Plots will be saved to: /home/raed/Documents/Masters_project_SFL_servers/results/plots/05
# Weights will be saved to: /home/raed/Documents/Masters_project_SFL_servers/weights/05

# %% [markdown]
# ## 3. Load MNIST dataset

# %%
transform = transforms.ToTensor()

train_dataset = datasets.MNIST(
    root=DATA_DIR,
    train=True,
    download=True,
    transform=transform,
)

test_dataset = datasets.MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=transform,
)

print("Train samples:", len(train_dataset))
print("Test samples:", len(test_dataset))
# Out:
# Train samples: 60000
# Test samples: 10000

# %% [markdown]
# ## 4. Create non-IID client datasets
#
# Each client receives samples from only one label.
#
# Example: client 1 gets label 0, client 2 gets label 1, ..., client 10 gets label 9.

# %%
def get_targets(dataset):
    if hasattr(dataset, "targets"):
        targets = dataset.targets
        if torch.is_tensor(targets):
            targets = targets.cpu().numpy()
        return np.array(targets)
    return np.array([dataset[i][1] for i in range(len(dataset))])


def create_one_label_client_subsets(dataset, num_clients: int, seed: int, max_samples_per_client=None):
    targets = get_targets(dataset)
    unique_labels = sorted(np.unique(targets).tolist())

    if num_clients > len(unique_labels):
        raise ValueError("num_clients cannot be greater than the number of labels for one-label-per-client setup.")

    selected_labels = unique_labels[:num_clients]
    rng = np.random.default_rng(seed)

    subsets = []
    client_label_map = {}

    for client_id, label in enumerate(selected_labels):
        label_indices = np.where(targets == label)[0]
        rng.shuffle(label_indices)

        if max_samples_per_client is not None:
            label_indices = label_indices[:max_samples_per_client]

        subsets.append(Subset(dataset, label_indices.tolist()))
        client_label_map[client_id] = label

    return subsets, client_label_map


client_subsets, client_label_map = create_one_label_client_subsets(
    train_dataset,
    num_clients=NUM_CLIENTS,
    seed=SEED,
    max_samples_per_client=MAX_SAMPLES_PER_CLIENT,
)

for client_id, subset in enumerate(client_subsets):
    print(f"Client {client_id + 1}: label={client_label_map[client_id]}, samples={len(subset)}")

sample_counts = [len(subset) for subset in client_subsets]
print("Total samples used:", sum(sample_counts))
# Out:
# Client 1: label=0, samples=5923
# Client 2: label=1, samples=6742
# Client 3: label=2, samples=5958
# Client 4: label=3, samples=6131
# Client 5: label=4, samples=5842
# Client 6: label=5, samples=5421
# Client 7: label=6, samples=5918
# Client 8: label=7, samples=6265
# Client 9: label=8, samples=5851
# Client 10: label=9, samples=5949
# Total samples used: 60000

# %% [markdown]
# ## 5. Data loaders
#
# FL and SFL use the same deterministic batch order for each client and round.

# %%
def make_client_loader(client_id: int, round_id: int, method_tag: str):
    # Same seed formula for FL and SFL ensures identical batch order.
    loader_seed = SEED + round_id * 1000 + client_id
    generator = torch.Generator().manual_seed(loader_seed)

    return DataLoader(
        client_subsets[client_id],
        batch_size=BATCH_SIZE,
        shuffle=True,
        generator=generator,
    )


test_loader = DataLoader(
    test_dataset,
    batch_size=TEST_BATCH_SIZE,
    shuffle=False,
)

# %% [markdown]
# ## 6. Models

# %%
from collections import OrderedDict

class FullModel(nn.Module):
    """
    Full FL model for notebook 05.

    Four-layer MLP architecture:
        Flatten
        fc1: 784 -> 256
        ReLU
        fc2: 256 -> 128
        ReLU
        fc3: 128 -> 10
        ReLU
        fc4: 10 -> 10

    SFL split:
        Client side: fc1 + ReLU + fc2 + ReLU
        Server side: fc3 + ReLU + fc4
    """

    def __init__(self, input_dim=28 * 28, hidden_dim1=256, hidden_dim2=128, hidden_dim3=10, num_classes=10):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_dim2, hidden_dim3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_dim3, num_classes)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        x = self.relu3(self.fc3(x))
        return self.fc4(x)


class ClientModel(nn.Module):
    """
    SFL client-side model.

    Contains:
        Flatten -> fc1 -> ReLU -> fc2 -> ReLU

    The cut-layer activation has shape [batch_size, 128].
    """

    def __init__(self, input_dim=28 * 28, hidden_dim1=256, hidden_dim2=128):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.relu2 = nn.ReLU()

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu1(self.fc1(x))
        return self.relu2(self.fc2(x))


class ServerModel(nn.Module):
    """
    SFL server-side model.

    Contains:
        fc3: 128 -> 10
        ReLU
        fc4: 10 -> 10
    """

    def __init__(self, hidden_dim2=128, hidden_dim3=10, num_classes=10):
        super().__init__()
        self.fc3 = nn.Linear(hidden_dim2, hidden_dim3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_dim3, num_classes)

    def forward(self, x):
        x = self.relu3(self.fc3(x))
        return self.fc4(x)


def full_to_client_state(full_state):
    """
    Extract client-side weights from the full model.
    Client side contains fc1 and fc2.
    """
    return OrderedDict({
        "fc1.weight": full_state["fc1.weight"].clone(),
        "fc1.bias": full_state["fc1.bias"].clone(),
        "fc2.weight": full_state["fc2.weight"].clone(),
        "fc2.bias": full_state["fc2.bias"].clone(),
    })


def full_to_server_state(full_state):
    """
    Extract server-side weights from the full model.
    Server side contains fc3 and fc4.
    """
    return OrderedDict({
        "fc3.weight": full_state["fc3.weight"].clone(),
        "fc3.bias": full_state["fc3.bias"].clone(),
        "fc4.weight": full_state["fc4.weight"].clone(),
        "fc4.bias": full_state["fc4.bias"].clone(),
    })


def split_to_full_state(client_state, server_state):
    """
    Reconstruct a full model state_dict from SFL client and server states.
    This is used to evaluate and compare SFL against FL.
    """
    return OrderedDict({
        "fc1.weight": client_state["fc1.weight"].clone(),
        "fc1.bias": client_state["fc1.bias"].clone(),
        "fc2.weight": client_state["fc2.weight"].clone(),
        "fc2.bias": client_state["fc2.bias"].clone(),
        "fc3.weight": server_state["fc3.weight"].clone(),
        "fc3.bias": server_state["fc3.bias"].clone(),
        "fc4.weight": server_state["fc4.weight"].clone(),
        "fc4.bias": server_state["fc4.bias"].clone(),
    })

# %% [markdown]
# ## 7. State dictionary helpers

# %%
def get_state_dict(model: nn.Module):
    return OrderedDict((k, v.detach().cpu().clone()) for k, v in model.state_dict().items())


def load_state_dict_to_model(model: nn.Module, state_dict):
    model.load_state_dict(state_dict, strict=True)


def full_to_client_state(full_state):
    """
    Extract the client-side part of the full 4-layer model.

    Split used in this notebook:
        Client side: fc1 + fc2
        Server side: fc3 + fc4
    """
    return OrderedDict({
        "fc1.weight": full_state["fc1.weight"].clone(),
        "fc1.bias": full_state["fc1.bias"].clone(),
        "fc2.weight": full_state["fc2.weight"].clone(),
        "fc2.bias": full_state["fc2.bias"].clone(),
    })


def full_to_server_state(full_state):
    """
    Extract the server-side part of the full 4-layer model.

    Split used in this notebook:
        Client side: fc1 + fc2
        Server side: fc3 + fc4
    """
    return OrderedDict({
        "fc3.weight": full_state["fc3.weight"].clone(),
        "fc3.bias": full_state["fc3.bias"].clone(),
        "fc4.weight": full_state["fc4.weight"].clone(),
        "fc4.bias": full_state["fc4.bias"].clone(),
    })


def split_to_full_state(client_state, server_state):
    """
    Reconstruct the full 4-layer FL model from the SFL client and server states.

    Full model: fc1 + fc2 + fc3 + fc4.
    """
    return OrderedDict({
        "fc1.weight": client_state["fc1.weight"].clone(),
        "fc1.bias": client_state["fc1.bias"].clone(),
        "fc2.weight": client_state["fc2.weight"].clone(),
        "fc2.bias": client_state["fc2.bias"].clone(),
        "fc3.weight": server_state["fc3.weight"].clone(),
        "fc3.bias": server_state["fc3.bias"].clone(),
        "fc4.weight": server_state["fc4.weight"].clone(),
        "fc4.bias": server_state["fc4.bias"].clone(),
    })


def fedavg_state_dicts(state_dicts, sample_counts):
    total_samples = sum(sample_counts)
    avg_state = OrderedDict()

    for key in state_dicts[0].keys():
        avg_tensor = torch.zeros_like(state_dicts[0][key], dtype=torch.float32)
        for state, n in zip(state_dicts, sample_counts):
            avg_tensor += state[key].float() * (n / total_samples)
        avg_state[key] = avg_tensor

    return avg_state


def aggregate_client_layers_with_fl_server(client_side_states, sample_counts):
    """
    Aggregate only the client-owned SFL layers using the client-side FL aggregator.

    In the corrected architecture, the SFL server should not directly see or
    aggregate these client-side weights. This function represents the separate
    FL aggregation domain for the client layers fc1 + fc2.
    """
    return fedavg_state_dicts(client_side_states, sample_counts)


def aggregate_server_layers_with_sfl_server(server_side_states, sample_counts):
    """
    Aggregate only the server-owned SFL layers using the SFL server aggregator.

    These are the layers after the cut, fc3 + fc4 in this 4-layer notebook.
    This keeps server-side aggregation conceptually separate from client-side FL.
    """
    return fedavg_state_dicts(server_side_states, sample_counts)


def l2_distance_state_dicts(state_a, state_b):
    total_sq = 0.0
    for key in state_a.keys():
        diff = state_a[key].float() - state_b[key].float()
        total_sq += torch.sum(diff ** 2).item()
    return total_sq ** 0.5

# %% [markdown]
# ## 8. Evaluation function

# %%
@torch.no_grad()
def evaluate_model(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    criterion = nn.CrossEntropyLoss()

    total_loss = 0.0
    correct = 0
    total = 0

    for x, y in loader:
        x = x.to(device)
        y = y.to(device)

        logits = model(x)
        loss = criterion(logits, y)

        total_loss += loss.item() * y.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    return total_loss / total, correct / total

# %% [markdown]
# ## 9. FL client training

# %%
def train_fl_client(start_global_state, train_loader: DataLoader, local_epochs: int, lr: float, device: torch.device):
    model = FullModel().to(device)
    load_state_dict_to_model(model, start_global_state)

    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr)

    for _ in range(local_epochs):
        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

    return get_state_dict(model)

# %% [markdown]
# ## 10. SFL training with separated aggregation domains
#
# Each client trains a client-side copy and a corresponding server-side copy for the round. After local training, the client-side layers are aggregated by a separate FL aggregation domain, while the server-side layers are aggregated by the SFL server. The reconstructed full model is used only for evaluation.

# %%
def train_sfl_client_design1(start_client_state, start_server_state, train_loader: DataLoader, local_epochs: int, lr: float, device: torch.device):
    client_model = ClientModel().to(device)
    server_model = ServerModel().to(device)

    load_state_dict_to_model(client_model, start_client_state)
    load_state_dict_to_model(server_model, start_server_state)

    client_model.train()
    server_model.train()

    criterion = nn.CrossEntropyLoss()
    client_optimizer = optim.SGD(client_model.parameters(), lr=lr)
    server_optimizer = optim.SGD(server_model.parameters(), lr=lr)

    for _ in range(local_epochs):
        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)

            client_optimizer.zero_grad()
            server_optimizer.zero_grad()

            smashed_data = client_model(x)
            smashed_data_detached = smashed_data.detach().requires_grad_(True)

            logits = server_model(smashed_data_detached)
            loss = criterion(logits, y)
            loss.backward()

            grad_to_client = smashed_data_detached.grad.clone()
            server_optimizer.step()

            smashed_data.backward(grad_to_client)
            client_optimizer.step()

    return get_state_dict(client_model), get_state_dict(server_model)

# %% [markdown]
# ## 11. Initialise FL and SFL from identical weights

# %%
set_seed(SEED)
initial_full_model = FullModel()
initial_full_state = get_state_dict(initial_full_model)

fl_global_state = copy.deepcopy(initial_full_state)

# SFL client-side global state belongs to the separate client-side FL aggregation domain.
sfl_client_fl_global_state = full_to_client_state(initial_full_state)

# SFL server-side global state belongs to the SFL server aggregation domain.
sfl_server_global_state = full_to_server_state(initial_full_state)

print("Initial FL and SFL states prepared from the same full model.")

# Sanity check: the client and server states must contain the expected split layers.
print("SFL client-side FL aggregator keys:", list(sfl_client_fl_global_state.keys()))
print("SFL server-side aggregator keys:", list(sfl_server_global_state.keys()))
assert "fc1.weight" in sfl_client_fl_global_state and "fc2.weight" in sfl_client_fl_global_state
assert "fc3.weight" in sfl_server_global_state and "fc4.weight" in sfl_server_global_state
# Out:
# Initial FL and SFL states prepared from the same full model.
# SFL client-side FL aggregator keys: ['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias']
# SFL server-side aggregator keys: ['fc3.weight', 'fc3.bias', 'fc4.weight', 'fc4.bias']

# %% [markdown]
# ## 12. Run 100 rounds and evaluate global accuracy after every round

# %%
results = []

for round_id in range(1, ROUNDS + 1):

    # get_round_lr() is called here once per communication round.
    # The same current_lr is then passed to every FL and SFL client in this round.
    current_lr = get_round_lr(round_id)
    print(f"Learning rate this round: {current_lr:.6f}")
    print(f"\n========== Round {round_id}/{ROUNDS} ==========")
    round_start_time = time.perf_counter()

    # -------------------------
    # FL local training
    # -------------------------
    fl_start_time = time.perf_counter()
    fl_client_states = []

    for client_id in range(NUM_CLIENTS):
        loader = make_client_loader(client_id, round_id, method_tag="fl")
        trained_state = train_fl_client(
            start_global_state=fl_global_state,
            train_loader=loader,
            local_epochs=LOCAL_EPOCHS,
            lr=current_lr,
            device=device,
        )
        fl_client_states.append(trained_state)

    fl_global_state = fedavg_state_dicts(fl_client_states, sample_counts)
    fl_time = time.perf_counter() - fl_start_time

    # Save only global model every round to avoid too many files.
    torch.save(fl_global_state, os.path.join(FL_WEIGHTS_DIR, f"fl_round_{round_id:03d}_global.pth"))

    # -------------------------
    # SFL local training with separated aggregators
    # -------------------------
    sfl_start_time = time.perf_counter()
    sfl_client_side_states = []
    sfl_server_side_states = []

    for client_id in range(NUM_CLIENTS):
        loader = make_client_loader(client_id, round_id, method_tag="sfl")
        trained_client_state, trained_server_state = train_sfl_client_design1(
            start_client_state=sfl_client_fl_global_state,
            start_server_state=sfl_server_global_state,
            train_loader=loader,
            local_epochs=LOCAL_EPOCHS,
            lr=current_lr,
            device=device,
        )
        sfl_client_side_states.append(trained_client_state)
        sfl_server_side_states.append(trained_server_state)

    # Client-owned SFL layers are aggregated by the client-side FL aggregator.
    # The SFL server should not directly see or aggregate these client-side weights.
    sfl_client_fl_global_state = aggregate_client_layers_with_fl_server(
        sfl_client_side_states,
        sample_counts,
    )

    # Server-owned SFL layers are aggregated by the SFL server-side aggregator.
    sfl_server_global_state = aggregate_server_layers_with_sfl_server(
        sfl_server_side_states,
        sample_counts,
    )

    # Reconstruct a full model only for evaluation and comparison with FL.
    # This is not a deployed object in the corrected SFL architecture.
    sfl_global_full_state = split_to_full_state(
        sfl_client_fl_global_state,
        sfl_server_global_state,
    )
    sfl_time = time.perf_counter() - sfl_start_time

    torch.save(
        sfl_client_fl_global_state,
        os.path.join(SFL_CLIENT_FL_WEIGHTS_DIR, f"sfl_round_{round_id:03d}_client_side_fl_global.pth"),
    )
    torch.save(
        sfl_server_global_state,
        os.path.join(SFL_SERVER_WEIGHTS_DIR, f"sfl_round_{round_id:03d}_server_side_global.pth"),
    )
    torch.save(
        sfl_global_full_state,
        os.path.join(SFL_EVAL_WEIGHTS_DIR, f"sfl_round_{round_id:03d}_full_reconstructed_for_eval_only.pth"),
    )

    # -------------------------
    # Evaluate global models after aggregation
    # -------------------------
    eval_start_time = time.perf_counter()

    fl_eval_model = FullModel().to(device)
    load_state_dict_to_model(fl_eval_model, fl_global_state)
    fl_test_loss, fl_test_acc = evaluate_model(fl_eval_model, test_loader, device)

    sfl_eval_model = FullModel().to(device)
    load_state_dict_to_model(sfl_eval_model, sfl_global_full_state)
    sfl_test_loss, sfl_test_acc = evaluate_model(sfl_eval_model, test_loader, device)

    eval_time = time.perf_counter() - eval_start_time
    total_round_time = time.perf_counter() - round_start_time

    global_l2 = l2_distance_state_dicts(fl_global_state, sfl_global_full_state)

    results.append({
        "round": round_id,
        "fl_test_loss": fl_test_loss,
        "fl_test_accuracy": fl_test_acc,
        "sfl_test_loss": sfl_test_loss,
        "sfl_test_accuracy": sfl_test_acc,
        "fl_minus_sfl_accuracy": fl_test_acc - sfl_test_acc,
        "global_l2_distance_fl_vs_sfl": global_l2,
        "fl_time_sec": fl_time,
        "sfl_time_sec": sfl_time,
        "evaluation_time_sec": eval_time,
        "total_round_time_sec": total_round_time,
    })

    print(
        f"Round {round_id:03d} | "
        f"FL acc={fl_test_acc:.4f}, SFL acc={sfl_test_acc:.4f}, "
        f"L2={global_l2:.6f}, "
        f"FL time={fl_time:.1f}s, SFL time={sfl_time:.1f}s"
    )

results_df = pd.DataFrame(results)
display(results_df)
# Out:
# Learning rate this round: 0.040000
#
# ========== Round 1/200 ==========
# Round 001 | FL acc=0.0983, SFL acc=0.0983, L2=0.000000, FL time=3.1s, SFL time=2.9s
# Learning rate this round: 0.039800
#
# ========== Round 2/200 ==========
# Round 002 | FL acc=0.0982, SFL acc=0.0982, L2=0.000000, FL time=2.6s, SFL time=3.1s
# Learning rate this round: 0.039601
#
# ========== Round 3/200 ==========
# Round 003 | FL acc=0.0982, SFL acc=0.0982, L2=0.000000, FL time=2.8s, SFL time=2.9s
# Learning rate this round: 0.039403
#
# ========== Round 4/200 ==========
# Round 004 | FL acc=0.1304, SFL acc=0.1304, L2=0.000000, FL time=2.8s, SFL time=2.9s
# Learning rate this round: 0.039206
#
# ========== Round 5/200 ==========
# Round 005 | FL acc=0.1393, SFL acc=0.1393, L2=0.000000, FL time=2.6s, SFL time=3.1s
# Learning rate this round: 0.039010
#
# ========== Round 6/200 ==========
# Round 006 | FL acc=0.1401, SFL acc=0.1401, L2=0.000000, FL time=2.9s, SFL time=2.9s
# Learning rate this round: 0.038815
#
# ========== Round 7/200 ==========
# Round 007 | FL acc=0.1939, SFL acc=0.1939, L2=0.000000, FL time=2.6s, SFL time=2.7s
# Learning rate this round: 0.038621
#
# ========== Round 8/200 ==========
# Round 008 | FL acc=0.1912, SFL acc=0.1912, L2=0.000000, FL time=2.6s, SFL time=2.7s
# Learning rate this round: 0.038428
#
# ========== Round 9/200 ==========
# Round 009 | FL acc=0.2669, SFL acc=0.2669, L2=0.000000, FL time=2.6s, SFL time=2.9s
# Learning rate this round: 0.038236
#
# ========== Round 10/200 ==========
# Round 010 | FL acc=0.2374, SFL acc=0.2374, L2=0.000000, FL time=2.6s, SFL time=2.7s
# Learning rate this round: 0.038044
#
# ========== Round 11/200 ==========
# Round 011 | FL acc=0.2842, SFL acc=0.2842, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.037854
#
# ========== Round 12/200 ==========
# Round 012 | FL acc=0.2113, SFL acc=0.2113, L2=0.000000, FL time=2.5s, SFL time=3.1s
# Learning rate this round: 0.037665
#
# ========== Round 13/200 ==========
# Round 013 | FL acc=0.2831, SFL acc=0.2831, L2=0.000000, FL time=2.7s, SFL time=3.1s
# Learning rate this round: 0.037477
#
# ========== Round 14/200 ==========
# Round 014 | FL acc=0.2954, SFL acc=0.2954, L2=0.000000, FL time=2.6s, SFL time=2.7s
# Learning rate this round: 0.037289
#
# ========== Round 15/200 ==========
# Round 015 | FL acc=0.1270, SFL acc=0.1270, L2=0.000000, FL time=2.9s, SFL time=3.0s
# Learning rate this round: 0.037103
#
# ========== Round 16/200 ==========
# Round 016 | FL acc=0.3464, SFL acc=0.3464, L2=0.000000, FL time=2.9s, SFL time=2.9s
# Learning rate this round: 0.036917
#
# ========== Round 17/200 ==========
# Round 017 | FL acc=0.1466, SFL acc=0.1466, L2=0.000000, FL time=2.5s, SFL time=3.0s
# Learning rate this round: 0.036733
#
# ========== Round 18/200 ==========
# Round 018 | FL acc=0.2086, SFL acc=0.2086, L2=0.000000, FL time=2.6s, SFL time=2.8s
# Learning rate this round: 0.036549
#
# ========== Round 19/200 ==========
# Round 019 | FL acc=0.1356, SFL acc=0.1356, L2=0.000000, FL time=2.9s, SFL time=3.1s
# Learning rate this round: 0.036366
#
# ========== Round 20/200 ==========
# Round 020 | FL acc=0.1004, SFL acc=0.1004, L2=0.000000, FL time=3.0s, SFL time=3.1s
# Learning rate this round: 0.036184
#
# ========== Round 21/200 ==========
# Round 021 | FL acc=0.1317, SFL acc=0.1317, L2=0.000000, FL time=3.0s, SFL time=3.2s
# Learning rate this round: 0.036003
#
# ========== Round 22/200 ==========
# Round 022 | FL acc=0.1730, SFL acc=0.1730, L2=0.000000, FL time=2.7s, SFL time=3.0s
# Learning rate this round: 0.035823
#
# ========== Round 23/200 ==========
# Round 023 | FL acc=0.2105, SFL acc=0.2105, L2=0.000000, FL time=2.9s, SFL time=3.1s
# Learning rate this round: 0.035644
#
# ========== Round 24/200 ==========
# Round 024 | FL acc=0.1187, SFL acc=0.1187, L2=0.000000, FL time=2.6s, SFL time=3.2s
# Learning rate this round: 0.035466
#
# ========== Round 25/200 ==========
# Round 025 | FL acc=0.2405, SFL acc=0.2405, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.035289
#
# ========== Round 26/200 ==========
# Round 026 | FL acc=0.2573, SFL acc=0.2573, L2=0.000000, FL time=3.0s, SFL time=3.2s
# Learning rate this round: 0.035112
#
# ========== Round 27/200 ==========
# Round 027 | FL acc=0.1869, SFL acc=0.1869, L2=0.000000, FL time=3.0s, SFL time=3.4s
# Learning rate this round: 0.034937
#
# ========== Round 28/200 ==========
# Round 028 | FL acc=0.1817, SFL acc=0.1817, L2=0.000000, FL time=3.3s, SFL time=3.4s
# Learning rate this round: 0.034762
#
# ========== Round 29/200 ==========
# Round 029 | FL acc=0.2778, SFL acc=0.2778, L2=0.000000, FL time=2.9s, SFL time=3.2s
# Learning rate this round: 0.034588
#
# ========== Round 30/200 ==========
# Round 030 | FL acc=0.0994, SFL acc=0.0994, L2=0.000000, FL time=2.8s, SFL time=3.2s
# Learning rate this round: 0.034415
#
# ========== Round 31/200 ==========
# Round 031 | FL acc=0.2647, SFL acc=0.2647, L2=0.000000, FL time=2.8s, SFL time=3.3s
# Learning rate this round: 0.034243
#
# ========== Round 32/200 ==========
# Round 032 | FL acc=0.1595, SFL acc=0.1595, L2=0.000000, FL time=3.5s, SFL time=3.2s
# Learning rate this round: 0.034072
#
# ========== Round 33/200 ==========
# Round 033 | FL acc=0.2227, SFL acc=0.2227, L2=0.000000, FL time=2.7s, SFL time=3.0s
# Learning rate this round: 0.033902
#
# ========== Round 34/200 ==========
# Round 034 | FL acc=0.0996, SFL acc=0.0996, L2=0.000000, FL time=2.7s, SFL time=3.0s
# Learning rate this round: 0.033732
#
# ========== Round 35/200 ==========
# Round 035 | FL acc=0.2301, SFL acc=0.2301, L2=0.000000, FL time=2.7s, SFL time=2.9s
# Learning rate this round: 0.033564
#
# ========== Round 36/200 ==========
# Round 036 | FL acc=0.2545, SFL acc=0.2545, L2=0.000000, FL time=2.9s, SFL time=3.1s
# Learning rate this round: 0.033396
#
# ========== Round 37/200 ==========
# Round 037 | FL acc=0.2628, SFL acc=0.2628, L2=0.000000, FL time=2.9s, SFL time=3.1s
# Learning rate this round: 0.033229
#
# ========== Round 38/200 ==========
# Round 038 | FL acc=0.2212, SFL acc=0.2212, L2=0.000000, FL time=2.9s, SFL time=3.0s
# Learning rate this round: 0.033063
#
# ========== Round 39/200 ==========
# Round 039 | FL acc=0.2475, SFL acc=0.2475, L2=0.000000, FL time=2.9s, SFL time=3.0s
# Learning rate this round: 0.032897
#
# ========== Round 40/200 ==========
# Round 040 | FL acc=0.2460, SFL acc=0.2460, L2=0.000000, FL time=2.8s, SFL time=3.1s
# Learning rate this round: 0.032733
#
# ========== Round 41/200 ==========
# Round 041 | FL acc=0.2635, SFL acc=0.2635, L2=0.000000, FL time=2.8s, SFL time=3.0s
# Learning rate this round: 0.032569
#
# ========== Round 42/200 ==========
# Round 042 | FL acc=0.2222, SFL acc=0.2222, L2=0.000000, FL time=2.8s, SFL time=3.2s
# Learning rate this round: 0.032406
#
# ========== Round 43/200 ==========
# Round 043 | FL acc=0.2751, SFL acc=0.2751, L2=0.000000, FL time=2.8s, SFL time=3.0s
# Learning rate this round: 0.032244
#
# ========== Round 44/200 ==========
# Round 044 | FL acc=0.1717, SFL acc=0.1717, L2=0.000000, FL time=3.0s, SFL time=3.1s
# Learning rate this round: 0.032083
#
# ========== Round 45/200 ==========
# Round 045 | FL acc=0.2805, SFL acc=0.2805, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.031923
#
# ========== Round 46/200 ==========
# Round 046 | FL acc=0.2390, SFL acc=0.2390, L2=0.000000, FL time=3.0s, SFL time=3.2s
# Learning rate this round: 0.031763
#
# ========== Round 47/200 ==========
# Round 047 | FL acc=0.2698, SFL acc=0.2698, L2=0.000000, FL time=2.9s, SFL time=3.5s
# Learning rate this round: 0.031604
#
# ========== Round 48/200 ==========
# Round 048 | FL acc=0.2417, SFL acc=0.2417, L2=0.000000, FL time=3.4s, SFL time=3.3s
# Learning rate this round: 0.031446
#
# ========== Round 49/200 ==========
# Round 049 | FL acc=0.2484, SFL acc=0.2484, L2=0.000000, FL time=4.4s, SFL time=4.1s
# Learning rate this round: 0.031289
#
# ========== Round 50/200 ==========
# Round 050 | FL acc=0.2725, SFL acc=0.2725, L2=0.000000, FL time=4.4s, SFL time=3.8s
# Learning rate this round: 0.031133
#
# ========== Round 51/200 ==========
# Round 051 | FL acc=0.2657, SFL acc=0.2657, L2=0.000000, FL time=4.4s, SFL time=4.6s
# Learning rate this round: 0.030977
#
# ========== Round 52/200 ==========
# Round 052 | FL acc=0.2516, SFL acc=0.2516, L2=0.000000, FL time=3.7s, SFL time=4.4s
# Learning rate this round: 0.030822
#
# ========== Round 53/200 ==========
# Round 053 | FL acc=0.2761, SFL acc=0.2761, L2=0.000000, FL time=3.7s, SFL time=4.2s
# Learning rate this round: 0.030668
#
# ========== Round 54/200 ==========
# Round 054 | FL acc=0.2407, SFL acc=0.2407, L2=0.000000, FL time=4.0s, SFL time=4.6s
# Learning rate this round: 0.030515
#
# ========== Round 55/200 ==========
# Round 055 | FL acc=0.2715, SFL acc=0.2715, L2=0.000000, FL time=3.6s, SFL time=4.1s
# Learning rate this round: 0.030362
#
# ========== Round 56/200 ==========
# Round 056 | FL acc=0.2645, SFL acc=0.2645, L2=0.000000, FL time=3.8s, SFL time=4.1s
# Learning rate this round: 0.030210
#
# ========== Round 57/200 ==========
# Round 057 | FL acc=0.2834, SFL acc=0.2834, L2=0.000000, FL time=3.8s, SFL time=4.4s
# Learning rate this round: 0.030059
#
# ========== Round 58/200 ==========
# Round 058 | FL acc=0.3343, SFL acc=0.3343, L2=0.000000, FL time=4.1s, SFL time=4.1s
# Learning rate this round: 0.029909
#
# ========== Round 59/200 ==========
# Round 059 | FL acc=0.3103, SFL acc=0.3103, L2=0.000000, FL time=3.9s, SFL time=4.3s
# Learning rate this round: 0.029759
#
# ========== Round 60/200 ==========
# Round 060 | FL acc=0.3706, SFL acc=0.3706, L2=0.000000, FL time=4.1s, SFL time=4.0s
# Learning rate this round: 0.029610
#
# ========== Round 61/200 ==========
# Round 061 | FL acc=0.2873, SFL acc=0.2873, L2=0.000000, FL time=3.5s, SFL time=3.8s
# Learning rate this round: 0.029462
#
# ========== Round 62/200 ==========
# Round 062 | FL acc=0.3418, SFL acc=0.3418, L2=0.000000, FL time=3.6s, SFL time=4.5s
# Learning rate this round: 0.029315
#
# ========== Round 63/200 ==========
# Round 063 | FL acc=0.3124, SFL acc=0.3124, L2=0.000000, FL time=3.9s, SFL time=4.3s
# Learning rate this round: 0.029168
#
# ========== Round 64/200 ==========
# Round 064 | FL acc=0.3469, SFL acc=0.3469, L2=0.000000, FL time=3.7s, SFL time=4.5s
# Learning rate this round: 0.029023
#
# ========== Round 65/200 ==========
# Round 065 | FL acc=0.2919, SFL acc=0.2919, L2=0.000000, FL time=3.8s, SFL time=4.0s
# Learning rate this round: 0.028878
#
# ========== Round 66/200 ==========
# Round 066 | FL acc=0.3576, SFL acc=0.3576, L2=0.000000, FL time=3.8s, SFL time=4.0s
# Learning rate this round: 0.028733
#
# ========== Round 67/200 ==========
# Round 067 | FL acc=0.2952, SFL acc=0.2952, L2=0.000000, FL time=3.8s, SFL time=4.1s
# Learning rate this round: 0.028589
#
# ========== Round 68/200 ==========
# Round 068 | FL acc=0.3733, SFL acc=0.3733, L2=0.000000, FL time=3.9s, SFL time=3.9s
# Learning rate this round: 0.028447
#
# ========== Round 69/200 ==========
# Round 069 | FL acc=0.3003, SFL acc=0.3003, L2=0.000000, FL time=3.7s, SFL time=4.2s
# Learning rate this round: 0.028304
#
# ========== Round 70/200 ==========
# Round 070 | FL acc=0.4047, SFL acc=0.4047, L2=0.000000, FL time=3.8s, SFL time=4.2s
# Learning rate this round: 0.028163
#
# ========== Round 71/200 ==========
# Round 071 | FL acc=0.3570, SFL acc=0.3570, L2=0.000000, FL time=3.8s, SFL time=4.4s
# Learning rate this round: 0.028022
#
# ========== Round 72/200 ==========
# Round 072 | FL acc=0.4122, SFL acc=0.4122, L2=0.000000, FL time=4.3s, SFL time=4.1s
# Learning rate this round: 0.027882
#
# ========== Round 73/200 ==========
# Round 073 | FL acc=0.3304, SFL acc=0.3304, L2=0.000000, FL time=4.1s, SFL time=4.2s
# Learning rate this round: 0.027742
#
# ========== Round 74/200 ==========
# Round 074 | FL acc=0.4306, SFL acc=0.4306, L2=0.000000, FL time=3.9s, SFL time=4.5s
# Learning rate this round: 0.027604
#
# ========== Round 75/200 ==========
# Round 075 | FL acc=0.3223, SFL acc=0.3223, L2=0.000000, FL time=3.8s, SFL time=4.2s
# Learning rate this round: 0.027466
#
# ========== Round 76/200 ==========
# Round 076 | FL acc=0.4352, SFL acc=0.4352, L2=0.000000, FL time=4.0s, SFL time=4.1s
# Learning rate this round: 0.027328
#
# ========== Round 77/200 ==========
# Round 077 | FL acc=0.3446, SFL acc=0.3446, L2=0.000000, FL time=4.0s, SFL time=4.6s
# Learning rate this round: 0.027192
#
# ========== Round 78/200 ==========
# Round 078 | FL acc=0.4239, SFL acc=0.4239, L2=0.000000, FL time=3.8s, SFL time=4.2s
# Learning rate this round: 0.027056
#
# ========== Round 79/200 ==========
# Round 079 | FL acc=0.3563, SFL acc=0.3563, L2=0.000000, FL time=3.9s, SFL time=4.1s
# Learning rate this round: 0.026921
#
# ========== Round 80/200 ==========
# Round 080 | FL acc=0.4081, SFL acc=0.4081, L2=0.000000, FL time=4.1s, SFL time=4.1s
# Learning rate this round: 0.026786
#
# ========== Round 81/200 ==========
# Round 081 | FL acc=0.3678, SFL acc=0.3678, L2=0.000000, FL time=4.2s, SFL time=4.3s
# Learning rate this round: 0.026652
#
# ========== Round 82/200 ==========
# Round 082 | FL acc=0.4138, SFL acc=0.4138, L2=0.000000, FL time=4.0s, SFL time=4.1s
# Learning rate this round: 0.026519
#
# ========== Round 83/200 ==========
# Round 083 | FL acc=0.3904, SFL acc=0.3904, L2=0.000000, FL time=3.9s, SFL time=4.4s
# Learning rate this round: 0.026386
#
# ========== Round 84/200 ==========
# Round 084 | FL acc=0.4125, SFL acc=0.4125, L2=0.000000, FL time=3.6s, SFL time=4.3s
# Learning rate this round: 0.026254
#
# ========== Round 85/200 ==========
# Round 085 | FL acc=0.3784, SFL acc=0.3784, L2=0.000000, FL time=3.8s, SFL time=4.2s
# Learning rate this round: 0.026123
#
# ========== Round 86/200 ==========
# Round 086 | FL acc=0.4082, SFL acc=0.4082, L2=0.000000, FL time=3.8s, SFL time=4.0s
# Learning rate this round: 0.025992
#
# ========== Round 87/200 ==========
# Round 087 | FL acc=0.3818, SFL acc=0.3818, L2=0.000000, FL time=3.5s, SFL time=4.0s
# Learning rate this round: 0.025862
#
# ========== Round 88/200 ==========
# Round 088 | FL acc=0.4224, SFL acc=0.4224, L2=0.000000, FL time=3.7s, SFL time=3.7s
# Learning rate this round: 0.025733
#
# ========== Round 89/200 ==========
# Round 089 | FL acc=0.4036, SFL acc=0.4036, L2=0.000000, FL time=3.8s, SFL time=4.4s
# Learning rate this round: 0.025604
#
# ========== Round 90/200 ==========
# Round 090 | FL acc=0.4557, SFL acc=0.4557, L2=0.000000, FL time=3.5s, SFL time=3.9s
# Learning rate this round: 0.025476
#
# ========== Round 91/200 ==========
# Round 091 | FL acc=0.4255, SFL acc=0.4255, L2=0.000000, FL time=3.7s, SFL time=4.4s
# Learning rate this round: 0.025349
#
# ========== Round 92/200 ==========
# Round 092 | FL acc=0.4503, SFL acc=0.4503, L2=0.000000, FL time=3.6s, SFL time=4.7s
# Learning rate this round: 0.025222
#
# ========== Round 93/200 ==========
# Round 093 | FL acc=0.4523, SFL acc=0.4523, L2=0.000000, FL time=3.6s, SFL time=4.4s
# Learning rate this round: 0.025096
#
# ========== Round 94/200 ==========
# Round 094 | FL acc=0.4841, SFL acc=0.4841, L2=0.000000, FL time=3.5s, SFL time=3.8s
# Learning rate this round: 0.024971
#
# ========== Round 95/200 ==========
# Round 095 | FL acc=0.4575, SFL acc=0.4575, L2=0.000000, FL time=3.6s, SFL time=4.3s
# Learning rate this round: 0.024846
#
# ========== Round 96/200 ==========
# Round 096 | FL acc=0.4931, SFL acc=0.4931, L2=0.000000, FL time=4.0s, SFL time=4.2s
# Learning rate this round: 0.024722
#
# ========== Round 97/200 ==========
# Round 097 | FL acc=0.5090, SFL acc=0.5090, L2=0.000000, FL time=3.5s, SFL time=4.0s
# Learning rate this round: 0.024598
#
# ========== Round 98/200 ==========
# Round 098 | FL acc=0.5265, SFL acc=0.5265, L2=0.000000, FL time=3.8s, SFL time=4.0s
# Learning rate this round: 0.024475
#
# ========== Round 99/200 ==========
# Round 099 | FL acc=0.5247, SFL acc=0.5247, L2=0.000000, FL time=3.6s, SFL time=3.9s
# Learning rate this round: 0.024353
#
# ========== Round 100/200 ==========
# Round 100 | FL acc=0.5272, SFL acc=0.5272, L2=0.000000, FL time=3.8s, SFL time=4.4s
# Learning rate this round: 0.024231
#
# ========== Round 101/200 ==========
# Round 101 | FL acc=0.5229, SFL acc=0.5229, L2=0.000000, FL time=3.6s, SFL time=4.2s
# Learning rate this round: 0.024110
#
# ========== Round 102/200 ==========
# Round 102 | FL acc=0.5275, SFL acc=0.5275, L2=0.000000, FL time=3.7s, SFL time=4.0s
# Learning rate this round: 0.023989
#
# ========== Round 103/200 ==========
# Round 103 | FL acc=0.5350, SFL acc=0.5350, L2=0.000000, FL time=3.7s, SFL time=4.0s
# Learning rate this round: 0.023869
#
# ========== Round 104/200 ==========
# Round 104 | FL acc=0.5280, SFL acc=0.5280, L2=0.000000, FL time=3.7s, SFL time=3.8s
# Learning rate this round: 0.023750
#
# ========== Round 105/200 ==========
# Round 105 | FL acc=0.5336, SFL acc=0.5336, L2=0.000000, FL time=3.8s, SFL time=4.0s
# Learning rate this round: 0.023631
#
# ========== Round 106/200 ==========
# Round 106 | FL acc=0.5408, SFL acc=0.5408, L2=0.000000, FL time=3.7s, SFL time=3.9s
# Learning rate this round: 0.023513
#
# ========== Round 107/200 ==========
# Round 107 | FL acc=0.5404, SFL acc=0.5404, L2=0.000000, FL time=3.7s, SFL time=3.7s
# Learning rate this round: 0.023395
#
# ========== Round 108/200 ==========
# Round 108 | FL acc=0.5347, SFL acc=0.5347, L2=0.000000, FL time=3.9s, SFL time=4.2s
# Learning rate this round: 0.023278
#
# ========== Round 109/200 ==========
# Round 109 | FL acc=0.5530, SFL acc=0.5530, L2=0.000000, FL time=3.7s, SFL time=5.4s
# Learning rate this round: 0.023162
#
# ========== Round 110/200 ==========
# Round 110 | FL acc=0.5079, SFL acc=0.5079, L2=0.000000, FL time=3.7s, SFL time=4.3s
# Learning rate this round: 0.023046
#
# ========== Round 111/200 ==========
# Round 111 | FL acc=0.5466, SFL acc=0.5466, L2=0.000000, FL time=3.6s, SFL time=4.4s
# Learning rate this round: 0.022931
#
# ========== Round 112/200 ==========
# Round 112 | FL acc=0.5237, SFL acc=0.5237, L2=0.000000, FL time=3.6s, SFL time=4.0s
# Learning rate this round: 0.022816
#
# ========== Round 113/200 ==========
# Round 113 | FL acc=0.5527, SFL acc=0.5527, L2=0.000000, FL time=3.7s, SFL time=4.4s
# Learning rate this round: 0.022702
#
# ========== Round 114/200 ==========
# Round 114 | FL acc=0.5354, SFL acc=0.5354, L2=0.000000, FL time=3.5s, SFL time=4.3s
# Learning rate this round: 0.022589
#
# ========== Round 115/200 ==========
# Round 115 | FL acc=0.5300, SFL acc=0.5300, L2=0.000000, FL time=3.6s, SFL time=4.0s
# Learning rate this round: 0.022476
#
# ========== Round 116/200 ==========
# Round 116 | FL acc=0.5156, SFL acc=0.5156, L2=0.000000, FL time=3.7s, SFL time=4.0s
# Learning rate this round: 0.022363
#
# ========== Round 117/200 ==========
# Round 117 | FL acc=0.5470, SFL acc=0.5470, L2=0.000000, FL time=3.8s, SFL time=3.2s
# Learning rate this round: 0.022252
#
# ========== Round 118/200 ==========
# Round 118 | FL acc=0.5345, SFL acc=0.5345, L2=0.000000, FL time=3.0s, SFL time=3.3s
# Learning rate this round: 0.022140
#
# ========== Round 119/200 ==========
# Round 119 | FL acc=0.5615, SFL acc=0.5615, L2=0.000000, FL time=3.2s, SFL time=3.3s
# Learning rate this round: 0.022030
#
# ========== Round 120/200 ==========
# Round 120 | FL acc=0.5277, SFL acc=0.5277, L2=0.000000, FL time=3.0s, SFL time=3.4s
# Learning rate this round: 0.021919
#
# ========== Round 121/200 ==========
# Round 121 | FL acc=0.5770, SFL acc=0.5770, L2=0.000000, FL time=3.1s, SFL time=3.4s
# Learning rate this round: 0.021810
#
# ========== Round 122/200 ==========
# Round 122 | FL acc=0.5429, SFL acc=0.5429, L2=0.000000, FL time=3.1s, SFL time=3.4s
# Learning rate this round: 0.021701
#
# ========== Round 123/200 ==========
# Round 123 | FL acc=0.5776, SFL acc=0.5776, L2=0.000000, FL time=2.9s, SFL time=3.5s
# Learning rate this round: 0.021592
#
# ========== Round 124/200 ==========
# Round 124 | FL acc=0.5667, SFL acc=0.5667, L2=0.000000, FL time=3.2s, SFL time=3.5s
# Learning rate this round: 0.021484
#
# ========== Round 125/200 ==========
# Round 125 | FL acc=0.5753, SFL acc=0.5753, L2=0.000000, FL time=3.1s, SFL time=3.4s
# Learning rate this round: 0.021377
#
# ========== Round 126/200 ==========
# Round 126 | FL acc=0.5547, SFL acc=0.5547, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.021270
#
# ========== Round 127/200 ==========
# Round 127 | FL acc=0.5835, SFL acc=0.5835, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.021164
#
# ========== Round 128/200 ==========
# Round 128 | FL acc=0.5618, SFL acc=0.5618, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.021058
#
# ========== Round 129/200 ==========
# Round 129 | FL acc=0.5770, SFL acc=0.5770, L2=0.000000, FL time=3.0s, SFL time=3.4s
# Learning rate this round: 0.020953
#
# ========== Round 130/200 ==========
# Round 130 | FL acc=0.5610, SFL acc=0.5610, L2=0.000000, FL time=3.2s, SFL time=3.3s
# Learning rate this round: 0.020848
#
# ========== Round 131/200 ==========
# Round 131 | FL acc=0.5788, SFL acc=0.5788, L2=0.000000, FL time=3.2s, SFL time=3.6s
# Learning rate this round: 0.020744
#
# ========== Round 132/200 ==========
# Round 132 | FL acc=0.5704, SFL acc=0.5704, L2=0.000000, FL time=3.2s, SFL time=3.3s
# Learning rate this round: 0.020640
#
# ========== Round 133/200 ==========
# Round 133 | FL acc=0.6014, SFL acc=0.6014, L2=0.000000, FL time=3.1s, SFL time=3.4s
# Learning rate this round: 0.020537
#
# ========== Round 134/200 ==========
# Round 134 | FL acc=0.5839, SFL acc=0.5839, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.020434
#
# ========== Round 135/200 ==========
# Round 135 | FL acc=0.6052, SFL acc=0.6052, L2=0.000000, FL time=3.2s, SFL time=3.3s
# Learning rate this round: 0.020332
#
# ========== Round 136/200 ==========
# Round 136 | FL acc=0.5895, SFL acc=0.5895, L2=0.000000, FL time=3.2s, SFL time=3.4s
# Learning rate this round: 0.020230
#
# ========== Round 137/200 ==========
# Round 137 | FL acc=0.6085, SFL acc=0.6085, L2=0.000000, FL time=3.2s, SFL time=3.4s
# Learning rate this round: 0.020129
#
# ========== Round 138/200 ==========
# Round 138 | FL acc=0.5718, SFL acc=0.5718, L2=0.000000, FL time=3.3s, SFL time=3.3s
# Learning rate this round: 0.020028
#
# ========== Round 139/200 ==========
# Round 139 | FL acc=0.6136, SFL acc=0.6136, L2=0.000000, FL time=3.2s, SFL time=3.4s
# Learning rate this round: 0.019928
#
# ========== Round 140/200 ==========
# Round 140 | FL acc=0.5977, SFL acc=0.5977, L2=0.000000, FL time=2.9s, SFL time=3.8s
# Learning rate this round: 0.019829
#
# ========== Round 141/200 ==========
# Round 141 | FL acc=0.6217, SFL acc=0.6217, L2=0.000000, FL time=3.1s, SFL time=3.4s
# Learning rate this round: 0.019729
#
# ========== Round 142/200 ==========
# Round 142 | FL acc=0.6073, SFL acc=0.6073, L2=0.000000, FL time=2.9s, SFL time=3.3s
# Learning rate this round: 0.019631
#
# ========== Round 143/200 ==========
# Round 143 | FL acc=0.6096, SFL acc=0.6096, L2=0.000000, FL time=3.0s, SFL time=3.4s
# Learning rate this round: 0.019533
#
# ========== Round 144/200 ==========
# Round 144 | FL acc=0.6101, SFL acc=0.6101, L2=0.000000, FL time=3.0s, SFL time=3.3s
# Learning rate this round: 0.019435
#
# ========== Round 145/200 ==========
# Round 145 | FL acc=0.6079, SFL acc=0.6079, L2=0.000000, FL time=3.2s, SFL time=3.6s
# Learning rate this round: 0.019338
#
# ========== Round 146/200 ==========
# Round 146 | FL acc=0.6031, SFL acc=0.6031, L2=0.000000, FL time=3.0s, SFL time=3.4s
# Learning rate this round: 0.019241
#
# ========== Round 147/200 ==========
# Round 147 | FL acc=0.5959, SFL acc=0.5959, L2=0.000000, FL time=3.0s, SFL time=3.3s
# Learning rate this round: 0.019145
#
# ========== Round 148/200 ==========
# Round 148 | FL acc=0.5932, SFL acc=0.5932, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.019049
#
# ========== Round 149/200 ==========
# Round 149 | FL acc=0.6011, SFL acc=0.6011, L2=0.000000, FL time=3.2s, SFL time=3.3s
# Learning rate this round: 0.018954
#
# ========== Round 150/200 ==========
# Round 150 | FL acc=0.5879, SFL acc=0.5879, L2=0.000000, FL time=3.1s, SFL time=3.3s
# Learning rate this round: 0.018859
#
# ========== Round 151/200 ==========
# Round 151 | FL acc=0.6193, SFL acc=0.6193, L2=0.000000, FL time=3.1s, SFL time=3.5s
# Learning rate this round: 0.018765
#
# ========== Round 152/200 ==========
# Round 152 | FL acc=0.6183, SFL acc=0.6183, L2=0.000000, FL time=3.0s, SFL time=3.3s
# Learning rate this round: 0.018671
#
# ========== Round 153/200 ==========
# Round 153 | FL acc=0.6240, SFL acc=0.6240, L2=0.000000, FL time=2.9s, SFL time=3.0s
# Learning rate this round: 0.018578
#
# ========== Round 154/200 ==========
# Round 154 | FL acc=0.6172, SFL acc=0.6172, L2=0.000000, FL time=2.9s, SFL time=3.2s
# Learning rate this round: 0.018485
#
# ========== Round 155/200 ==========
# Round 155 | FL acc=0.6233, SFL acc=0.6233, L2=0.000000, FL time=2.5s, SFL time=2.8s
# Learning rate this round: 0.018392
#
# ========== Round 156/200 ==========
# Round 156 | FL acc=0.6125, SFL acc=0.6125, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.018300
#
# ========== Round 157/200 ==========
# Round 157 | FL acc=0.6265, SFL acc=0.6265, L2=0.000000, FL time=2.4s, SFL time=2.9s
# Learning rate this round: 0.018209
#
# ========== Round 158/200 ==========
# Round 158 | FL acc=0.6003, SFL acc=0.6003, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.018118
#
# ========== Round 159/200 ==========
# Round 159 | FL acc=0.6204, SFL acc=0.6204, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.018027
#
# ========== Round 160/200 ==========
# Round 160 | FL acc=0.5969, SFL acc=0.5969, L2=0.000000, FL time=2.7s, SFL time=2.8s
# Learning rate this round: 0.017937
#
# ========== Round 161/200 ==========
# Round 161 | FL acc=0.6294, SFL acc=0.6294, L2=0.000000, FL time=2.5s, SFL time=2.7s
# Learning rate this round: 0.017847
#
# ========== Round 162/200 ==========
# Round 162 | FL acc=0.6106, SFL acc=0.6106, L2=0.000000, FL time=2.5s, SFL time=2.7s
# Learning rate this round: 0.017758
#
# ========== Round 163/200 ==========
# Round 163 | FL acc=0.6311, SFL acc=0.6311, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.017669
#
# ========== Round 164/200 ==========
# Round 164 | FL acc=0.6178, SFL acc=0.6178, L2=0.000000, FL time=2.6s, SFL time=2.6s
# Learning rate this round: 0.017581
#
# ========== Round 165/200 ==========
# Round 165 | FL acc=0.6366, SFL acc=0.6366, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.017493
#
# ========== Round 166/200 ==========
# Round 166 | FL acc=0.6231, SFL acc=0.6231, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.017406
#
# ========== Round 167/200 ==========
# Round 167 | FL acc=0.6354, SFL acc=0.6354, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.017319
#
# ========== Round 168/200 ==========
# Round 168 | FL acc=0.6057, SFL acc=0.6057, L2=0.000000, FL time=2.4s, SFL time=2.7s
# Learning rate this round: 0.017232
#
# ========== Round 169/200 ==========
# Round 169 | FL acc=0.6391, SFL acc=0.6391, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.017146
#
# ========== Round 170/200 ==========
# Round 170 | FL acc=0.6284, SFL acc=0.6284, L2=0.000000, FL time=2.5s, SFL time=2.9s
# Learning rate this round: 0.017060
#
# ========== Round 171/200 ==========
# Round 171 | FL acc=0.6426, SFL acc=0.6426, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.016975
#
# ========== Round 172/200 ==========
# Round 172 | FL acc=0.6239, SFL acc=0.6239, L2=0.000000, FL time=2.6s, SFL time=2.6s
# Learning rate this round: 0.016890
#
# ========== Round 173/200 ==========
# Round 173 | FL acc=0.6458, SFL acc=0.6458, L2=0.000000, FL time=2.6s, SFL time=2.8s
# Learning rate this round: 0.016806
#
# ========== Round 174/200 ==========
# Round 174 | FL acc=0.6284, SFL acc=0.6284, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.016722
#
# ========== Round 175/200 ==========
# Round 175 | FL acc=0.6596, SFL acc=0.6596, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.016638
#
# ========== Round 176/200 ==========
# Round 176 | FL acc=0.6394, SFL acc=0.6394, L2=0.000000, FL time=2.4s, SFL time=2.8s
# Learning rate this round: 0.016555
#
# ========== Round 177/200 ==========
# Round 177 | FL acc=0.6587, SFL acc=0.6587, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.016472
#
# ========== Round 178/200 ==========
# Round 178 | FL acc=0.6362, SFL acc=0.6362, L2=0.000000, FL time=2.7s, SFL time=2.6s
# Learning rate this round: 0.016390
#
# ========== Round 179/200 ==========
# Round 179 | FL acc=0.6543, SFL acc=0.6543, L2=0.000000, FL time=2.5s, SFL time=2.7s
# Learning rate this round: 0.016308
#
# ========== Round 180/200 ==========
# Round 180 | FL acc=0.6354, SFL acc=0.6354, L2=0.000000, FL time=2.5s, SFL time=2.7s
# Learning rate this round: 0.016226
#
# ========== Round 181/200 ==========
# Round 181 | FL acc=0.6631, SFL acc=0.6631, L2=0.000000, FL time=2.7s, SFL time=2.7s
# Learning rate this round: 0.016145
#
# ========== Round 182/200 ==========
# Round 182 | FL acc=0.6473, SFL acc=0.6473, L2=0.000000, FL time=2.7s, SFL time=2.7s
# Learning rate this round: 0.016064
#
# ========== Round 183/200 ==========
# Round 183 | FL acc=0.6572, SFL acc=0.6572, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.015984
#
# ========== Round 184/200 ==========
# Round 184 | FL acc=0.6418, SFL acc=0.6418, L2=0.000000, FL time=2.4s, SFL time=2.5s
# Learning rate this round: 0.015904
#
# ========== Round 185/200 ==========
# Round 185 | FL acc=0.6666, SFL acc=0.6666, L2=0.000000, FL time=2.0s, SFL time=2.6s
# Learning rate this round: 0.015824
#
# ========== Round 186/200 ==========
# Round 186 | FL acc=0.6433, SFL acc=0.6433, L2=0.000000, FL time=2.4s, SFL time=2.5s
# Learning rate this round: 0.015745
#
# ========== Round 187/200 ==========
# Round 187 | FL acc=0.6619, SFL acc=0.6619, L2=0.000000, FL time=2.3s, SFL time=2.6s
# Learning rate this round: 0.015667
#
# ========== Round 188/200 ==========
# Round 188 | FL acc=0.6464, SFL acc=0.6464, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.015588
#
# ========== Round 189/200 ==========
# Round 189 | FL acc=0.6545, SFL acc=0.6545, L2=0.000000, FL time=2.7s, SFL time=2.7s
# Learning rate this round: 0.015510
#
# ========== Round 190/200 ==========
# Round 190 | FL acc=0.6421, SFL acc=0.6421, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.015433
#
# ========== Round 191/200 ==========
# Round 191 | FL acc=0.6599, SFL acc=0.6599, L2=0.000000, FL time=1.8s, SFL time=2.0s
# Learning rate this round: 0.015356
#
# ========== Round 192/200 ==========
# Round 192 | FL acc=0.6477, SFL acc=0.6477, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.015279
#
# ========== Round 193/200 ==========
# Round 193 | FL acc=0.6750, SFL acc=0.6750, L2=0.000000, FL time=2.5s, SFL time=2.3s
# Learning rate this round: 0.015202
#
# ========== Round 194/200 ==========
# Round 194 | FL acc=0.6670, SFL acc=0.6670, L2=0.000000, FL time=2.3s, SFL time=2.6s
# Learning rate this round: 0.015126
#
# ========== Round 195/200 ==========
# Round 195 | FL acc=0.6766, SFL acc=0.6766, L2=0.000000, FL time=2.5s, SFL time=2.6s
# Learning rate this round: 0.015051
#
# ========== Round 196/200 ==========
# Round 196 | FL acc=0.6654, SFL acc=0.6654, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.014976
#
# ========== Round 197/200 ==========
# Round 197 | FL acc=0.6814, SFL acc=0.6814, L2=0.000000, FL time=2.3s, SFL time=2.3s
# Learning rate this round: 0.014901
#
# ========== Round 198/200 ==========
# Round 198 | FL acc=0.6771, SFL acc=0.6771, L2=0.000000, FL time=2.4s, SFL time=2.6s
# Learning rate this round: 0.014826
#
# ========== Round 199/200 ==========
# Round 199 | FL acc=0.6775, SFL acc=0.6775, L2=0.000000, FL time=2.5s, SFL time=2.7s
# Learning rate this round: 0.014752
#
# ========== Round 200/200 ==========
# Round 200 | FL acc=0.6639, SFL acc=0.6639, L2=0.000000, FL time=2.4s, SFL time=2.5s
#      round  fl_test_loss  fl_test_accuracy  sfl_test_loss  sfl_test_accuracy  \
# 0        1      2.335180            0.0983       2.335180             0.0983
# 1        2      2.504405            0.0982       2.504405             0.0982
# 2        3      2.494209            0.0982       2.494209             0.0982
# 3        4      2.378121            0.1304       2.378121             0.1304
# 4        5      2.288703            0.1393       2.288703             0.1393
# ..     ...           ...               ...            ...                ...
# 195    196      1.145154            0.6654       1.145154             0.6654
# 196    197      1.141098            0.6814       1.141098             0.6814
# 197    198      1.137943            0.6771       1.137943             0.6771
# 198    199      1.135838            0.6775       1.135838             0.6775
# 199    200      1.136701            0.6639       1.136701             0.6639
#
#      fl_minus_sfl_accuracy  global_l2_distance_fl_vs_sfl  fl_time_sec  \
# 0                      0.0                           0.0     3.052637
# 1                      0.0                           0.0     2.604780
# 2                      0.0                           0.0     2.798557
# 3                      0.0                           0.0     2.788421
# 4                      0.0                           0.0     2.623793
# ..                     ...                           ...          ...
# 195                    0.0                           0.0     2.401066
# 196                    0.0                           0.0     2.341686
# 197                    0.0                           0.0     2.390129
# 198                    0.0                           0.0     2.468157
# 199                    0.0                           0.0     2.387586
#
#      sfl_time_sec  evaluation_time_sec  total_round_time_sec
# 0        2.892223             0.603493              6.555756
# 1        3.072061             0.613024              6.292967
# 2        2.862920             0.599301              6.263841
# 3        2.935761             0.584571              6.311821
# 4        3.055395             0.638153              6.320637
# ..            ...                  ...                   ...
# 195      2.568691             0.552509              5.524902
# 196      2.341869             0.553784              5.239859
# 197      2.564589             0.560320              5.517724
# 198      2.722049             0.553314              5.746398
# 199      2.541235             0.549881              5.481359
#
# [200 rows x 11 columns]

# %% [markdown]
# ## 13. Save CSV results

# %%
results_csv_path = os.path.join(CSV_DIR, f"fl_vs_sfl_noniid_one_label_{ROUNDS}_rounds.csv")
results_df.to_csv(results_csv_path, index=False)
print("Saved results CSV to:", results_csv_path)
# Out:
# Saved results CSV to: /home/raed/Documents/Masters_project_SFL_servers/results/csv/05/fl_vs_sfl_noniid_one_label_200_rounds.csv

# %% [markdown]
# ## 14. Plot FL vs SFL accuracy

# %%
accuracy_plot_path = os.path.join(PLOTS_DIR, f"fl_vs_sfl_noniid_one_label_accuracy_{ROUNDS}_rounds.png")

plt.figure(figsize=(9, 5))
plt.plot(results_df["round"], results_df["fl_test_accuracy"], marker="o", label="FL global model")
plt.plot(results_df["round"], results_df["sfl_test_accuracy"], marker="o", label="SFL global reconstructed model")
plt.xlabel("Communication round")
plt.ylabel("Test accuracy")
plt.title("FL vs SFL Accuracy: Non-IID, One Label per Client, No Attack, Decaying LR, 4-layer MLP, 200 Rounds, MNIST")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(accuracy_plot_path, dpi=200)
plt.show()

print("Saved accuracy plot to:", accuracy_plot_path)
# Out:
# Saved accuracy plot to: /home/raed/Documents/Masters_project_SFL_servers/results/plots/05/fl_vs_sfl_noniid_one_label_accuracy_200_rounds.png

# %% [markdown]
# ## 15. Plot FL vs SFL loss

# %%
loss_plot_path = os.path.join(PLOTS_DIR, f"fl_vs_sfl_noniid_one_label_loss_{ROUNDS}_rounds.png")

plt.figure(figsize=(9, 5))
plt.plot(results_df["round"], results_df["fl_test_loss"], marker="o", label="FL global model")
plt.plot(results_df["round"], results_df["sfl_test_loss"], marker="o", label="SFL global reconstructed model")
plt.xlabel("Communication round")
plt.ylabel("Test loss")
plt.title("FL vs SFL Loss: Non-IID, One Label per Client, No Attack, Decaying LR, 4-layer MLP, 200 Rounds, MNIST")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(loss_plot_path, dpi=200)
plt.show()

print("Saved loss plot to:", loss_plot_path)
# Out:
# Saved loss plot to: /home/raed/Documents/Masters_project_SFL_servers/results/plots/05/fl_vs_sfl_noniid_one_label_loss_200_rounds.png

# %% [markdown]
# ## 16. Short report text for README / thesis notes

# %%
summary_text = f"""
Experiment: FL vs SFL under extreme non-IID data distribution.

Architecture: 784 -> 256 -> 128 -> 10, split as client 784 -> 256 and server 256 -> 128 -> 10.
Dataset: MNIST.
Clients: {NUM_CLIENTS}.
Non-IID setting: each client receives data from only one label/class.
Communication rounds: {ROUNDS}.
Local epochs per client per round: {LOCAL_EPOCHS}.

The global model was evaluated after every aggregation round on the full MNIST test set.
The final FL accuracy was {results_df['fl_test_accuracy'].iloc[-1]:.4f}.
The final SFL accuracy was {results_df['sfl_test_accuracy'].iloc[-1]:.4f}.

The saved CSV file contains one row per communication round, giving {ROUNDS} accuracy values for FL and {ROUNDS} accuracy values for SFL.
"""

summary_path = os.path.join(CSV_DIR, f"fl_vs_sfl_noniid_one_label_summary_{ROUNDS}_rounds.txt")
with open(summary_path, "w", encoding="utf-8") as f:
    f.write(summary_text)

print(summary_text)
print("Saved summary text to:", summary_path)
# Out:
# Experiment: FL vs SFL under extreme non-IID data distribution.
#
# Architecture: 784 -> 256 -> 128 -> 10, split as client 784 -> 256 and server 256 -> 128 -> 10.
# Dataset: MNIST.
# Clients: 10.
# Non-IID setting: each client receives data from only one label/class.
# Communication rounds: 200.
# Local epochs per client per round: 1.
#
# The global model was evaluated after every aggregation round on the full MNIST test set.
# The final FL accuracy was 0.6639.
# The final SFL accuracy was 0.6639.
#
# The saved CSV file contains one row per communication round, giving 200 accuracy values for FL and 200 accuracy values for SFL.
#
# Saved summary text to: /home/raed/Documents/Masters_project_SFL_servers/results/csv/05/fl_vs_sfl_noniid_one_label_summary_200_rounds.txt

# %% [markdown]
# ## Comparison with the earlier 5-layer and 2-layer notebooks
#
# This version uses a 3-layer fully connected network:
#
# ```text
# Full FL model: 784 -> 256 -> 128 -> 10
# SFL client:    784 -> 256
# SFL server:    256 -> 128 -> 10
# ```
#
# Why this version is useful:
#
# 1. **It keeps SFL meaningful**
#    The client has one trainable layer and the server has two trainable layers.
#
# 2. **It is still simpler than the 5-layer model**
#    The previous 5-layer MLP was very unstable under one-label-per-client non-IID training.
#
# 3. **It gives more server-side depth than the 2-layer model**
#    The earlier 2-layer model had only one server-side layer. This version gives the server a deeper role while remaining easier to train than the 5-layer model.
#
# 4. **It keeps FL/SFL architecture aligned**
#    The FL-only clients train the same complete 3-layer model that is reconstructed from the SFL client and server states.
#
# Recommended next checks:
#
# - Watch whether the L2 distance remains close to zero.
# - Compare the accuracy curve against the 2-layer and 5-layer versions.
# - If accuracy collapses again, reduce `INITIAL_LR` from `0.01` to `0.005` before adding any stabilization tricks.
