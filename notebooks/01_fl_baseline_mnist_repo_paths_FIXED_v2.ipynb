# %% [markdown]
# FL on MNIST — Stage 1 and Stage 2 Notebook Guide
#
# This notebook-style guide contains both stages your supervisor asked for:
#
# Stage 1: 10 clients, IID split, MNIST, 2NN, accuracy vs training round
# Stage 2: 10 clients, non-IID split where each client has one label, MNIST, 2NN, accuracy vs training round
#
# You can copy the code cells into a Jupyter notebook, or keep them as a Python script.
#
# Cell 1 — Imports

# %%
import os

NOTEBOOK_ID = "01"

# --------------------------------------------------
# Base repository directory
# --------------------------------------------------
BASE_DIR = os.path.abspath("..")

# --------------------------------------------------
# Shared project folders
# --------------------------------------------------
DATA_DIR = os.path.join(BASE_DIR, "data")

RESULTS_DIR = os.path.join(BASE_DIR, "results")

CSV_DIR = os.path.join(RESULTS_DIR, "csv", NOTEBOOK_ID)

PLOTS_DIR = os.path.join(RESULTS_DIR, "plots", NOTEBOOK_ID)

WEIGHTS_DIR = os.path.join(BASE_DIR, "weights", NOTEBOOK_ID)

# --------------------------------------------------
# Create folders if missing
# --------------------------------------------------
os.makedirs(DATA_DIR, exist_ok=True)

os.makedirs(CSV_DIR, exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

os.makedirs(WEIGHTS_DIR, exist_ok=True)

# %%
import argparse
import copy
import random
from collections import OrderedDict, defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.optim import SGD
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms

# %% [markdown]
# Cell 2 — Reproducibility

# %%
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# %% [markdown]
# Cell 3 — Model: 2NN
#
# Why 2NN first:
#
# easier to debug than CNN
# faster to run
# enough to clearly show IID vs non-IID behavior in FL

# %%
class TwoNN(nn.Module):
    def __init__(self, input_dim=28 * 28, hidden_dim=200, num_classes=10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_classes),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Cell 4 — Model parameter utilities

# %%
def get_model_params(model: nn.Module):  # Returns a copy of the model's parameters as an OrderedDict
    return OrderedDict((k, v.detach().clone()) for k, v in model.state_dict().items())


def set_model_params(model: nn.Module, params):  # Sets the model's parameters from an OrderedDict
    model.load_state_dict(params, strict=True)


def subtract_params(new_params, old_params):  # Subtracts two sets of parameters
    return OrderedDict((k, new_params[k] - old_params[k]) for k in new_params.keys()) 


def add_params(a, b): # Adds two sets of parameters
    return OrderedDict((k, a[k] + b[k]) for k in a.keys())


def scale_params(params, scalar: float): # Scales a set of parameters by a scalar
    return OrderedDict((k, v * scalar) for k, v in params.items())


def zeros_like_params(params): # Creates a new set of parameters with the same keys but all values set to zero
    return OrderedDict((k, torch.zeros_like(v)) for k, v in params.items())

# %% [markdown]
# Cell 5 — Load MNIST
#
# Data is downloaded automatically into ./data.

# %%
def load_mnist(data_root: str = DATA_DIR): 
    transform = transforms.ToTensor()
    train_ds = datasets.MNIST(root=data_root, train=True, download=True, transform=transform)  #
    test_ds = datasets.MNIST(root=data_root, train=False, download=True, transform=transform)
    return train_ds, test_ds

# %% [markdown]
# Cell 6 — Stage 1 data partition: IID
#
# This shuffles all training samples and splits them equally among 10 clients.

# %%
# Randomly shuffles the dataset indices
# Divides them evenly across clients
# Creates a separate dataset for each client

def partition_iid(dataset, num_clients=10, seed=42):
    rng = np.random.default_rng(seed) # Generator function: whCreate a random number generator with the given seed for reproducibility
    indices = np.arange(len(dataset)) # Create an array of indices corresponding to the dataset samples
    rng.shuffle(indices) # Shuffle the indices to randomize the order of the samples

    shard_size = len(indices) // num_clients
    subsets = []
    for i in range(num_clients):
        start = i * shard_size
        end = (i + 1) * shard_size if i < num_clients - 1 else len(indices)
        subsets.append(Subset(dataset, indices[start:end].tolist())) # tolist() converts the numpy array slice to a Python list, which is required by the Subset class
    return subsets

# %% [markdown]
# Cell 7 — Stage 2 data partition: one-label non-IID
#
# This is the extreme non-IID setting your supervisor described:
#
# client 0 gets label 0 only
# client 1 gets label 1 only
# ...
# client 9 gets label 9 only

# %%
# This function does the following:
# make sure the number of clients is exactly 10
# create a dictionary that will map each label to a list of dataset positions
# scan through the whole dataset
# for each sample, put its index into the list for its label
# create an empty list of client datasets
# for each client ID from 0 to 9:
# take all indices of that label
# make a subset from the original dataset
# add it to the list
# return the list of client subsets

def partition_one_label_per_client(dataset, num_clients=10):
    if num_clients != 10:
        raise ValueError("This one-label-per-client stage is defined for exactly 10 clients.")

    label_to_indices = defaultdict(list) # if a new key is used for the first time, automatically create an empty list [] for it
    for idx, (_, label) in enumerate(dataset):
        label_to_indices[int(label)].append(idx)

    subsets = []
    for client_id in range(num_clients):
        subsets.append(Subset(dataset, label_to_indices[client_id]))
    return subsets

# %% [markdown]
# Cell 8 — DataLoaders

# %%
def make_loaders(train_subsets, test_ds, batch_size=64, test_batch_size=256):
    # Create a DataLoader for each client subset with the specified batch size and shuffling enabled for training, and a single DataLoader for the test dataset with a larger batch size and shuffling
    train_loaders = [
        DataLoader(subset, batch_size=batch_size, shuffle=True)
        for subset in train_subsets
    ]
    test_loader = DataLoader(test_ds, batch_size=test_batch_size, shuffle=False)
    return train_loaders, test_loader

# %% [markdown]
# Cell 9 — FL Client
#
# Each client:
#
# receives global parameters
# trains locally
# computes update = final params - initial params

# %%
class FLClient:
    def __init__(self, client_id, model, loader, lr, local_epochs, device):
        self.client_id = client_id
        self.model = model.to(device)
        self.loader = loader
        self.lr = lr
        self.local_epochs = local_epochs
        self.device = device

    def train(self, global_params):
        set_model_params(self.model, global_params)
        initial_params = get_model_params(self.model)

        self.model.train()
        optimizer = SGD(self.model.parameters(), lr=self.lr)
        criterion = nn.CrossEntropyLoss()

        loss_sum = 0.0
        count = 0

        for _ in range(self.local_epochs):
            for x, y in self.loader:
                x, y = x.to(self.device), y.to(self.device)
                optimizer.zero_grad()
                logits = self.model(x)
                loss = criterion(logits, y) # Compute the loss between the model's predictions (logits) and the true labels (y) using the cross-entropy loss function
                loss.backward()  # Compute the gradients of the loss with respect to the model parameters
                optimizer.step() #

                loss_sum += loss.item() * y.size(0)  # Accumulate the total loss across all samples in the loader, multiplying by the batch size to get the total loss for that batch
                count += y.size(0)  # Keep track of the total number of samples processed to compute the average loss

        final_params = get_model_params(self.model)
        update = subtract_params(final_params, initial_params)

        return {
            "client_id": self.client_id,
            "num_samples": len(self.loader.dataset),
            "update": update,
            "local_loss": loss_sum / max(count, 1),
        }

# %% [markdown]
# Cell 10 — FL Server (FedAvg)

# %%
class FLServer:
    def __init__(self, initial_params):
        self.global_params = initial_params

    def aggregate(self, client_results):
        total_samples = sum(r["num_samples"] for r in client_results)
        agg_update = zeros_like_params(client_results[0]["update"])

        for result in client_results:
            weight = result["num_samples"] / total_samples
            weighted_update = scale_params(result["update"], weight)
            
                    #             OrderedDict({
                    #     "layer1.weight": tensor(...),
                    #     "layer1.bias": tensor(...),
                    #     ...
                    # })
            agg_update = add_params(agg_update, weighted_update)  

        self.global_params = add_params(self.global_params, agg_update)

# %% [markdown]
# Cell 11 — Evaluation

# %%
def evaluate(model, loader, device):
    model.eval()
    criterion = nn.CrossEntropyLoss()

    correct = 0   # Initialize a counter for the number of correct predictions
    total = 0     # Initialize a counter for the total number of samples
    loss_sum = 0.0  # Initialize a variable to accumulate the total loss

    with torch.no_grad():  # Disable gradient computation for evaluation
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits = model(x)
            loss = criterion(logits, y)  # Compute the loss between the model's predictions (logits) and the true labels (y) using the cross-entropy loss function

            preds = logits.argmax(dim=1)
            correct += (preds == y).sum().item() # Add the number of correct predictions in the current batch to the total count of correct predictions 
            total += y.size(0)  # dimension 0 of y corresponds to the batch size, so this adds the number of samples in the current batch to the total count
            loss_sum += loss.item() * y.size(0)

    return {
        "accuracy": correct / total,
        "loss": loss_sum / total,
    }

# %% [markdown]
# Cell 12 — Main experiment runner
#
# This function runs either Stage 1 or Stage 2.

# %%
def run_federated_experiment(
    stage: str,
    data_root: str = DATA_DIR,
    num_clients: int = 10,
    rounds: int = 100,
    batch_size: int = 64,
    test_batch_size: int = 256,
    lr: float = 0.05,
    local_epochs: int = 1,
    hidden_dim: int = 200,
    seed: int = 42,
    device: str = "cpu",
):
    set_seed(seed)

    train_ds, test_ds = load_mnist(data_root)

    if stage == "iid":
        train_subsets = partition_iid(train_ds, num_clients=num_clients, seed=seed)
        title = "Stage 1: IID FL on MNIST"
        out_plot = "stage1_iid_accuracy_vs_round.png"
        out_csv = "stage1_iid_metrics.csv"
    elif stage == "label_noniid":
        train_subsets = partition_one_label_per_client(train_ds, num_clients=num_clients)
        title = "Stage 2: Extreme Non-IID FL (One Label per Client)"
        out_plot = "stage2_label_noniid_accuracy_vs_round.png"
        out_csv = "stage2_label_noniid_metrics.csv"
    else:
        raise ValueError("stage must be either 'iid' or 'label_noniid'")

    train_loaders, test_loader = make_loaders(
        train_subsets,
        test_ds,
        batch_size=batch_size,
        test_batch_size=test_batch_size,
    )

    base_model = TwoNN(hidden_dim=hidden_dim).to(device)
    initial_params = get_model_params(base_model)
    server = FLServer(initial_params=initial_params)

    clients = [
        FLClient(
            client_id=i,
            model=TwoNN(hidden_dim=hidden_dim),
            loader=train_loaders[i],
            lr=lr,
            local_epochs=local_epochs,
            device=device,
        )
        for i in range(num_clients)
    ]

    history = []

    for rnd in range(1, rounds + 1):
        global_params = copy.deepcopy(server.global_params)

        client_results = []
        for client in clients:
            result = client.train(global_params)
            client_results.append(result)

        server.aggregate(client_results)

        eval_model = TwoNN(hidden_dim=hidden_dim).to(device)
        set_model_params(eval_model, server.global_params)
        eval_result = evaluate(eval_model, test_loader, device=device)

        avg_local_loss = sum(r["local_loss"] for r in client_results) / len(client_results)

        history.append(
            {
                "round": rnd,
                "test_accuracy": eval_result["accuracy"],
                "test_loss": eval_result["loss"],
                "avg_client_local_loss": avg_local_loss,
            }
        )

        print(
            f"Round {rnd:02d} | "
            f"test_acc={eval_result['accuracy']:.4f} | "
            f"test_loss={eval_result['loss']:.4f} | "
            f"avg_local_loss={avg_local_loss:.4f}"
        )

    df = pd.DataFrame(history)
    df.to_csv(os.path.join(CSV_DIR, out_csv), index=False)

    plt.figure(figsize=(8, 4))
    plt.plot(df["round"], df["test_accuracy"], marker="o")
    plt.xlabel("Training Round")
    plt.ylabel("Test Accuracy")
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(PLOTS_DIR, out_plot))
    plt.show()

    print(f"\nSaved metrics to: {os.path.join(CSV_DIR, out_csv)}")
    print(f"Saved plot to:    {os.path.join(PLOTS_DIR, out_plot)}")

    return df

# %% [markdown]
# Cell 13 — Device setup

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# Cell 14 — Run Stage 1 (IID)

# %%
df_stage1 = run_federated_experiment(
    stage="iid",
    data_root=DATA_DIR,
    num_clients=10,
    rounds=100,
    batch_size=64,
    test_batch_size=256,
    lr=0.05,
    local_epochs=1,
    hidden_dim=200,
    seed=42,
    device=device,
)
# Out:
# Round 01 | test_acc=0.8057 | test_loss=1.0157 | avg_local_loss=1.6954
# Round 02 | test_acc=0.8639 | test_loss=0.5872 | avg_local_loss=0.7774
# Round 03 | test_acc=0.8825 | test_loss=0.4633 | avg_local_loss=0.5444
# Round 04 | test_acc=0.8925 | test_loss=0.4050 | avg_local_loss=0.4579
# Round 05 | test_acc=0.8989 | test_loss=0.3719 | avg_local_loss=0.4130
# Round 06 | test_acc=0.9029 | test_loss=0.3491 | avg_local_loss=0.3841
# Round 07 | test_acc=0.9076 | test_loss=0.3328 | avg_local_loss=0.3646
# Round 08 | test_acc=0.9106 | test_loss=0.3202 | avg_local_loss=0.3487
# Round 09 | test_acc=0.9142 | test_loss=0.3092 | avg_local_loss=0.3359
# Round 10 | test_acc=0.9170 | test_loss=0.3003 | avg_local_loss=0.3246
# Round 11 | test_acc=0.9185 | test_loss=0.2938 | avg_local_loss=0.3151
# Round 12 | test_acc=0.9204 | test_loss=0.2842 | avg_local_loss=0.3064
# Round 13 | test_acc=0.9223 | test_loss=0.2779 | avg_local_loss=0.2986
# Round 14 | test_acc=0.9231 | test_loss=0.2720 | avg_local_loss=0.2912
# Round 15 | test_acc=0.9254 | test_loss=0.2661 | avg_local_loss=0.2846
# Round 16 | test_acc=0.9261 | test_loss=0.2610 | avg_local_loss=0.2780
# Round 17 | test_acc=0.9283 | test_loss=0.2559 | avg_local_loss=0.2718
# Round 18 | test_acc=0.9294 | test_loss=0.2504 | avg_local_loss=0.2663
# Round 19 | test_acc=0.9311 | test_loss=0.2461 | avg_local_loss=0.2600
# Round 20 | test_acc=0.9320 | test_loss=0.2416 | avg_local_loss=0.2549
# Round 21 | test_acc=0.9333 | test_loss=0.2363 | avg_local_loss=0.2497
# Round 22 | test_acc=0.9353 | test_loss=0.2325 | avg_local_loss=0.2451
# Round 23 | test_acc=0.9356 | test_loss=0.2286 | avg_local_loss=0.2401
# Round 24 | test_acc=0.9377 | test_loss=0.2238 | avg_local_loss=0.2353
# Round 25 | test_acc=0.9391 | test_loss=0.2205 | avg_local_loss=0.2309
# Round 26 | test_acc=0.9397 | test_loss=0.2167 | avg_local_loss=0.2268
# Round 27 | test_acc=0.9413 | test_loss=0.2138 | avg_local_loss=0.2225
# Round 28 | test_acc=0.9410 | test_loss=0.2098 | avg_local_loss=0.2186
# Round 29 | test_acc=0.9433 | test_loss=0.2058 | avg_local_loss=0.2146
# Round 30 | test_acc=0.9437 | test_loss=0.2031 | avg_local_loss=0.2110
# Round 31 | test_acc=0.9441 | test_loss=0.1999 | avg_local_loss=0.2075
# Round 32 | test_acc=0.9449 | test_loss=0.1964 | avg_local_loss=0.2037
# Round 33 | test_acc=0.9462 | test_loss=0.1933 | avg_local_loss=0.2006
# Round 34 | test_acc=0.9465 | test_loss=0.1911 | avg_local_loss=0.1974
# Round 35 | test_acc=0.9464 | test_loss=0.1879 | avg_local_loss=0.1942
# Round 36 | test_acc=0.9471 | test_loss=0.1858 | avg_local_loss=0.1911
# Round 37 | test_acc=0.9472 | test_loss=0.1827 | avg_local_loss=0.1883
# Round 38 | test_acc=0.9494 | test_loss=0.1812 | avg_local_loss=0.1850
# Round 39 | test_acc=0.9492 | test_loss=0.1782 | avg_local_loss=0.1824
# Round 40 | test_acc=0.9499 | test_loss=0.1760 | avg_local_loss=0.1795
# Round 41 | test_acc=0.9508 | test_loss=0.1731 | avg_local_loss=0.1773
# Round 42 | test_acc=0.9511 | test_loss=0.1711 | avg_local_loss=0.1745
# Round 43 | test_acc=0.9518 | test_loss=0.1685 | avg_local_loss=0.1718
# Round 44 | test_acc=0.9520 | test_loss=0.1667 | avg_local_loss=0.1694
# Round 45 | test_acc=0.9534 | test_loss=0.1645 | avg_local_loss=0.1671
# Round 46 | test_acc=0.9539 | test_loss=0.1630 | avg_local_loss=0.1646
# Round 47 | test_acc=0.9540 | test_loss=0.1611 | avg_local_loss=0.1630
# Round 48 | test_acc=0.9543 | test_loss=0.1593 | avg_local_loss=0.1605
# Round 49 | test_acc=0.9551 | test_loss=0.1577 | avg_local_loss=0.1583
# Round 50 | test_acc=0.9553 | test_loss=0.1553 | avg_local_loss=0.1562
# Round 51 | test_acc=0.9557 | test_loss=0.1535 | avg_local_loss=0.1540
# Round 52 | test_acc=0.9556 | test_loss=0.1530 | avg_local_loss=0.1520
# Round 53 | test_acc=0.9565 | test_loss=0.1505 | avg_local_loss=0.1500
# Round 54 | test_acc=0.9566 | test_loss=0.1488 | avg_local_loss=0.1482
# Round 55 | test_acc=0.9569 | test_loss=0.1472 | avg_local_loss=0.1463
# Round 56 | test_acc=0.9575 | test_loss=0.1457 | avg_local_loss=0.1446
# Round 57 | test_acc=0.9581 | test_loss=0.1442 | avg_local_loss=0.1430
# Round 58 | test_acc=0.9582 | test_loss=0.1429 | avg_local_loss=0.1409
# Round 59 | test_acc=0.9588 | test_loss=0.1419 | avg_local_loss=0.1393
# Round 60 | test_acc=0.9596 | test_loss=0.1400 | avg_local_loss=0.1376
# Round 61 | test_acc=0.9602 | test_loss=0.1389 | avg_local_loss=0.1362
# Round 62 | test_acc=0.9600 | test_loss=0.1373 | avg_local_loss=0.1348
# Round 63 | test_acc=0.9604 | test_loss=0.1362 | avg_local_loss=0.1331
# Round 64 | test_acc=0.9610 | test_loss=0.1351 | avg_local_loss=0.1315
# Round 65 | test_acc=0.9615 | test_loss=0.1335 | avg_local_loss=0.1299
# Round 66 | test_acc=0.9615 | test_loss=0.1326 | avg_local_loss=0.1287
# Round 67 | test_acc=0.9625 | test_loss=0.1312 | avg_local_loss=0.1270
# Round 68 | test_acc=0.9621 | test_loss=0.1305 | avg_local_loss=0.1256
# Round 69 | test_acc=0.9619 | test_loss=0.1293 | avg_local_loss=0.1244
# Round 70 | test_acc=0.9617 | test_loss=0.1283 | avg_local_loss=0.1232
# Round 71 | test_acc=0.9632 | test_loss=0.1274 | avg_local_loss=0.1219
# Round 72 | test_acc=0.9640 | test_loss=0.1257 | avg_local_loss=0.1205
# Round 73 | test_acc=0.9635 | test_loss=0.1248 | avg_local_loss=0.1192
# Round 74 | test_acc=0.9632 | test_loss=0.1238 | avg_local_loss=0.1179
# Round 75 | test_acc=0.9642 | test_loss=0.1232 | avg_local_loss=0.1167
# Round 76 | test_acc=0.9642 | test_loss=0.1221 | avg_local_loss=0.1155
# Round 77 | test_acc=0.9643 | test_loss=0.1215 | avg_local_loss=0.1143
# Round 78 | test_acc=0.9652 | test_loss=0.1204 | avg_local_loss=0.1134
# Round 79 | test_acc=0.9653 | test_loss=0.1192 | avg_local_loss=0.1122
# Round 80 | test_acc=0.9650 | test_loss=0.1185 | avg_local_loss=0.1112
# Round 81 | test_acc=0.9661 | test_loss=0.1178 | avg_local_loss=0.1100
# Round 82 | test_acc=0.9654 | test_loss=0.1172 | avg_local_loss=0.1091
# Round 83 | test_acc=0.9655 | test_loss=0.1163 | avg_local_loss=0.1079
# Round 84 | test_acc=0.9663 | test_loss=0.1153 | avg_local_loss=0.1069
# Round 85 | test_acc=0.9669 | test_loss=0.1141 | avg_local_loss=0.1058
# Round 86 | test_acc=0.9668 | test_loss=0.1132 | avg_local_loss=0.1049
# Round 87 | test_acc=0.9668 | test_loss=0.1130 | avg_local_loss=0.1039
# Round 88 | test_acc=0.9669 | test_loss=0.1117 | avg_local_loss=0.1029
# Round 89 | test_acc=0.9672 | test_loss=0.1114 | avg_local_loss=0.1022
# Round 90 | test_acc=0.9670 | test_loss=0.1109 | avg_local_loss=0.1012
# Round 91 | test_acc=0.9674 | test_loss=0.1099 | avg_local_loss=0.1002
# Round 92 | test_acc=0.9678 | test_loss=0.1093 | avg_local_loss=0.0991
# Round 93 | test_acc=0.9683 | test_loss=0.1088 | avg_local_loss=0.0983
# Round 94 | test_acc=0.9681 | test_loss=0.1081 | avg_local_loss=0.0977
# Round 95 | test_acc=0.9682 | test_loss=0.1075 | avg_local_loss=0.0968
# Round 96 | test_acc=0.9689 | test_loss=0.1069 | avg_local_loss=0.0961
# Round 97 | test_acc=0.9690 | test_loss=0.1067 | avg_local_loss=0.0950
# Round 98 | test_acc=0.9690 | test_loss=0.1055 | avg_local_loss=0.0944
# Round 99 | test_acc=0.9694 | test_loss=0.1051 | avg_local_loss=0.0934
# Round 100 | test_acc=0.9693 | test_loss=0.1039 | avg_local_loss=0.0928
# Saved metrics to: /home/raed/Documents/Masters_project_SFL_servers/results/csv/01/stage1_iid_metrics.csv
# Saved plot to:    /home/raed/Documents/Masters_project_SFL_servers/results/plots/01/stage1_iid_accuracy_vs_round.png

# %% [markdown]
# Cell 15 — Run Stage 2 (One-label non-IID)

# %%
df_stage2 = run_federated_experiment(
    stage="label_noniid",
    data_root=DATA_DIR,
    num_clients=10,
    rounds=100,
    batch_size=64,
    test_batch_size=256,
    lr=0.05,
    local_epochs=1,
    hidden_dim=200,
    seed=42,
    device=device,
)
# Out:
# Round 01 | test_acc=0.2185 | test_loss=2.2316 | avg_local_loss=0.1035
# Round 02 | test_acc=0.3383 | test_loss=2.1534 | avg_local_loss=0.0617
# Round 03 | test_acc=0.3849 | test_loss=2.0874 | avg_local_loss=0.0463
# Round 04 | test_acc=0.4507 | test_loss=2.0298 | avg_local_loss=0.0389
# Round 05 | test_acc=0.5015 | test_loss=1.9784 | avg_local_loss=0.0344
# Round 06 | test_acc=0.5407 | test_loss=1.9310 | avg_local_loss=0.0316
# Round 07 | test_acc=0.5671 | test_loss=1.8867 | avg_local_loss=0.0294
# Round 08 | test_acc=0.5852 | test_loss=1.8457 | avg_local_loss=0.0274
# Round 09 | test_acc=0.5961 | test_loss=1.8061 | avg_local_loss=0.0259
# Round 10 | test_acc=0.6110 | test_loss=1.7675 | avg_local_loss=0.0252
# Round 11 | test_acc=0.6234 | test_loss=1.7318 | avg_local_loss=0.0241
# Round 12 | test_acc=0.6342 | test_loss=1.6971 | avg_local_loss=0.0232
# Round 13 | test_acc=0.6462 | test_loss=1.6635 | avg_local_loss=0.0224
# Round 14 | test_acc=0.6573 | test_loss=1.6319 | avg_local_loss=0.0220
# Round 15 | test_acc=0.6628 | test_loss=1.6005 | avg_local_loss=0.0212
# Round 16 | test_acc=0.6744 | test_loss=1.5696 | avg_local_loss=0.0206
# Round 17 | test_acc=0.6834 | test_loss=1.5407 | avg_local_loss=0.0204
# Round 18 | test_acc=0.6951 | test_loss=1.5117 | avg_local_loss=0.0197
# Round 19 | test_acc=0.6965 | test_loss=1.4850 | avg_local_loss=0.0195
# Round 20 | test_acc=0.6953 | test_loss=1.4605 | avg_local_loss=0.0188
# Round 21 | test_acc=0.7011 | test_loss=1.4355 | avg_local_loss=0.0186
# Round 22 | test_acc=0.7096 | test_loss=1.4092 | avg_local_loss=0.0180
# Round 23 | test_acc=0.7129 | test_loss=1.3848 | avg_local_loss=0.0179
# Round 24 | test_acc=0.7147 | test_loss=1.3626 | avg_local_loss=0.0173
# Round 25 | test_acc=0.7257 | test_loss=1.3388 | avg_local_loss=0.0172
# Round 26 | test_acc=0.7259 | test_loss=1.3163 | avg_local_loss=0.0168
# Round 27 | test_acc=0.7325 | test_loss=1.2935 | avg_local_loss=0.0165
# Round 28 | test_acc=0.7376 | test_loss=1.2734 | avg_local_loss=0.0163
# Round 29 | test_acc=0.7434 | test_loss=1.2543 | avg_local_loss=0.0160
# Round 30 | test_acc=0.7409 | test_loss=1.2369 | avg_local_loss=0.0157
# Round 31 | test_acc=0.7492 | test_loss=1.2153 | avg_local_loss=0.0156
# Round 32 | test_acc=0.7544 | test_loss=1.1959 | avg_local_loss=0.0153
# Round 33 | test_acc=0.7536 | test_loss=1.1789 | avg_local_loss=0.0154
# Round 34 | test_acc=0.7539 | test_loss=1.1651 | avg_local_loss=0.0147
# Round 35 | test_acc=0.7608 | test_loss=1.1479 | avg_local_loss=0.0146
# Round 36 | test_acc=0.7630 | test_loss=1.1277 | avg_local_loss=0.0149
# Round 37 | test_acc=0.7634 | test_loss=1.1143 | avg_local_loss=0.0143
# Round 38 | test_acc=0.7711 | test_loss=1.0954 | avg_local_loss=0.0142
# Round 39 | test_acc=0.7754 | test_loss=1.0828 | avg_local_loss=0.0138
# Round 40 | test_acc=0.7745 | test_loss=1.0689 | avg_local_loss=0.0136
# Round 41 | test_acc=0.7811 | test_loss=1.0561 | avg_local_loss=0.0135
# Round 42 | test_acc=0.7812 | test_loss=1.0427 | avg_local_loss=0.0139
# Round 43 | test_acc=0.7849 | test_loss=1.0290 | avg_local_loss=0.0133
# Round 44 | test_acc=0.7891 | test_loss=1.0126 | avg_local_loss=0.0131
# Round 45 | test_acc=0.7877 | test_loss=1.0034 | avg_local_loss=0.0130
# Round 46 | test_acc=0.7843 | test_loss=0.9925 | avg_local_loss=0.0130
# Round 47 | test_acc=0.8015 | test_loss=0.9757 | avg_local_loss=0.0130
# Round 48 | test_acc=0.7956 | test_loss=0.9672 | avg_local_loss=0.0122
# Round 49 | test_acc=0.7976 | test_loss=0.9559 | avg_local_loss=0.0125
# Round 50 | test_acc=0.7915 | test_loss=0.9461 | avg_local_loss=0.0124
# Round 51 | test_acc=0.7995 | test_loss=0.9344 | avg_local_loss=0.0123
# Round 52 | test_acc=0.7991 | test_loss=0.9266 | avg_local_loss=0.0123
# Round 53 | test_acc=0.8032 | test_loss=0.9158 | avg_local_loss=0.0119
# Round 54 | test_acc=0.8062 | test_loss=0.9041 | avg_local_loss=0.0120
# Round 55 | test_acc=0.8050 | test_loss=0.8958 | avg_local_loss=0.0121
# Round 56 | test_acc=0.8083 | test_loss=0.8859 | avg_local_loss=0.0117
# Round 57 | test_acc=0.8054 | test_loss=0.8811 | avg_local_loss=0.0114
# Round 58 | test_acc=0.8108 | test_loss=0.8694 | avg_local_loss=0.0115
# Round 59 | test_acc=0.8096 | test_loss=0.8615 | avg_local_loss=0.0114
# Round 60 | test_acc=0.8142 | test_loss=0.8517 | avg_local_loss=0.0114
# Round 61 | test_acc=0.8134 | test_loss=0.8446 | avg_local_loss=0.0113
# Round 62 | test_acc=0.8139 | test_loss=0.8363 | avg_local_loss=0.0112
# Round 63 | test_acc=0.8181 | test_loss=0.8287 | avg_local_loss=0.0109
# Round 64 | test_acc=0.8159 | test_loss=0.8218 | avg_local_loss=0.0109
# Round 65 | test_acc=0.8166 | test_loss=0.8160 | avg_local_loss=0.0107
# Round 66 | test_acc=0.8204 | test_loss=0.8055 | avg_local_loss=0.0110
# Round 67 | test_acc=0.8188 | test_loss=0.8006 | avg_local_loss=0.0105
# Round 68 | test_acc=0.8221 | test_loss=0.7921 | avg_local_loss=0.0107
# Round 69 | test_acc=0.8211 | test_loss=0.7861 | avg_local_loss=0.0103
# Round 70 | test_acc=0.8183 | test_loss=0.7832 | avg_local_loss=0.0106
# Round 71 | test_acc=0.8265 | test_loss=0.7745 | avg_local_loss=0.0103
# Round 72 | test_acc=0.8271 | test_loss=0.7693 | avg_local_loss=0.0103
# Round 73 | test_acc=0.8228 | test_loss=0.7620 | avg_local_loss=0.0103
# Round 74 | test_acc=0.8278 | test_loss=0.7574 | avg_local_loss=0.0102
# Round 75 | test_acc=0.8219 | test_loss=0.7537 | avg_local_loss=0.0103
# Round 76 | test_acc=0.8285 | test_loss=0.7485 | avg_local_loss=0.0102
# Round 77 | test_acc=0.8257 | test_loss=0.7433 | avg_local_loss=0.0100
# Round 78 | test_acc=0.8286 | test_loss=0.7360 | avg_local_loss=0.0097
# Round 79 | test_acc=0.8251 | test_loss=0.7366 | avg_local_loss=0.0096
# Round 80 | test_acc=0.8347 | test_loss=0.7228 | avg_local_loss=0.0099
# Round 81 | test_acc=0.8312 | test_loss=0.7204 | avg_local_loss=0.0098
# Round 82 | test_acc=0.8318 | test_loss=0.7166 | avg_local_loss=0.0093
# Round 83 | test_acc=0.8352 | test_loss=0.7089 | avg_local_loss=0.0098
# Round 84 | test_acc=0.8340 | test_loss=0.7069 | avg_local_loss=0.0095
# Round 85 | test_acc=0.8363 | test_loss=0.6990 | avg_local_loss=0.0095
# Round 86 | test_acc=0.8394 | test_loss=0.6946 | avg_local_loss=0.0092
# Round 87 | test_acc=0.8393 | test_loss=0.6915 | avg_local_loss=0.0093
# Round 88 | test_acc=0.8334 | test_loss=0.6894 | avg_local_loss=0.0094
# Round 89 | test_acc=0.8395 | test_loss=0.6855 | avg_local_loss=0.0095
# Round 90 | test_acc=0.8355 | test_loss=0.6834 | avg_local_loss=0.0091
# Round 91 | test_acc=0.8410 | test_loss=0.6748 | avg_local_loss=0.0091
# Round 92 | test_acc=0.8403 | test_loss=0.6720 | avg_local_loss=0.0089
# Round 93 | test_acc=0.8406 | test_loss=0.6689 | avg_local_loss=0.0089
# Round 94 | test_acc=0.8427 | test_loss=0.6635 | avg_local_loss=0.0089
# Round 95 | test_acc=0.8423 | test_loss=0.6621 | avg_local_loss=0.0091
# Round 96 | test_acc=0.8454 | test_loss=0.6548 | avg_local_loss=0.0093
# Round 97 | test_acc=0.8452 | test_loss=0.6529 | avg_local_loss=0.0090
# Round 98 | test_acc=0.8445 | test_loss=0.6500 | avg_local_loss=0.0086
# Round 99 | test_acc=0.8494 | test_loss=0.6439 | avg_local_loss=0.0090
# Round 100 | test_acc=0.8455 | test_loss=0.6416 | avg_local_loss=0.0087
# Saved metrics to: /home/raed/Documents/Masters_project_SFL_servers/results/csv/01/stage2_label_noniid_metrics.csv
# Saved plot to:    /home/raed/Documents/Masters_project_SFL_servers/results/plots/01/stage2_label_noniid_accuracy_vs_round.png

# %% [markdown]
# Cell 16 — Optional comparison plot in one figure

# %%
plt.figure(figsize=(8, 4))
plt.plot(df_stage1["round"], df_stage1["test_accuracy"], marker="o", label="Stage 1: IID")
plt.plot(df_stage2["round"], df_stage2["test_accuracy"], marker="s", label="Stage 2: One-label non-IID")
plt.xlabel("Training Round")
plt.ylabel("Test Accuracy")
plt.title("IID vs Extreme Non-IID on MNIST")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "iid_vs_label_noniid_comparison.png"))
plt.show()
